# %% [markdown]
# <img src="img/DN.png" style="float:right;width:150px">
#
# Module, Dateien einlesen und API
#
# # Übungen in dieser Lektion
#
# * [Modul finden und nutzen](#Aufgabe1)
# * [Eigenes Modul nutzen](#Aufgabe2)
# * [Datei einlesen und Zahlen summieren](#Aufgabe3)
# * [JSON Dateien verstehen](#Aufgabe4)
# * [JSON Dateien in Python öffnen](#Aufgabe5)
# * [JSON Daten auslesen](#Aufgabe6)
# * [Schlussaufgabe](#Aufgabe7)
# * [Zusatzaufgabe (anspruchsvoll)](#Aufgabe8)
#
# # Module
#
# Python ist modular aufgebaut. Das heisst, neben einem bestimmten Satz an schon vorhandenen Grundfunktionalitäten können **zusätzliche Funktionalitäten** mit der Hilfe von sogenannten **Modulen** hinzugefügt werden. Diese Module kann man selbst erstellen oder von anderen Entwicklern übernehmen. Module sind nichts anderes als Dateien mit Python Code.
#
# Der modulare Aufbau hilft, Code übersichtlich zu organisieren. Die Idee von Modulen ist die **Wiederverwertbarkeit von Code**. Genau so wie eine Funktion dazu dient, einen bestimmten Code innerhalb eines Programms mehrfach auszuführen, dienen Module dazu, Programmcode über mehrere Projekte hinweg wiederverwenden zu können.
#
# ## Ein bestehendens Modul verwenden
#
# Es existieren sogenannte [*Built-in Modules*](https://docs.python.org/3/py-modindex.html), welche sofort genutzt werden können, sobald man sie importiert hat:

# %%
import random

x = random.randint(1,100)

print(x)
# Out:
# 23

# %% [markdown]
# Das Modul **random** stellt Funktionen zur Erzeugung von Zufallszahlen bereit. Sobald wir das Modul mit dem `import` Befehl nutzbar gemacht haben, können wir auf die Funktionen des Moduls zugreifen, indem wir mit `random.funktion()` die entsprechenden Funktionen aufrufen. Wir müssen also jeweils vor den eigentlichen Funktionsnamen, hier `randint()`, den Modulnahmen, hier also `random` einfügen.
#
# Mit Hilfe der Funktion `dir()` können alle Funktionen (und Variablen) eines Moduls angezeigt werden:

# %%
import random

x = dir(random)

print(x)
# Out:
# ['BPF', 'LOG4', 'NV_MAGICCONST', 'RECIP_BPF', 'Random', 'SG_MAGICCONST', 'SystemRandom', 'TWOPI', '_Sequence', '_Set', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_accumulate', '_acos', '_bisect', '_ceil', '_cos', '_e', '_exp', '_inst', '_log', '_os', '_pi', '_random', '_repeat', '_sha512', '_sin', '_sqrt', '_test', '_test_generator', '_urandom', '_warn', 'betavariate', 'choice', 'choices', 'expovariate', 'gammavariate', 'gauss', 'getrandbits', 'getstate', 'lognormvariate', 'normalvariate', 'paretovariate', 'randint', 'random', 'randrange', 'sample', 'seed', 'setstate', 'shuffle', 'triangular', 'uniform', 'vonmisesvariate', 'weibullvariate']

# %% [markdown]
# Um ein Modul vernünftig anwenden zu können, muss man aber typischerweise die Dokumentation zum Modul zur Verfügung haben. Die offizielle Dokumentation zu den Built-in Modules von Python befindet sich unter [docs.python.org](https://docs.python.org) und entsprechend für das Modul *random* [hier](https://docs.python.org/3/library/random.html). Sich in diesen Dokumentationen zurechtzufinden ist eine wichtige Kompetenz für das Programmieren.
#
# Wenn man im Internet nach Hilfe sucht und bspw. eine entsprechende Funktion findet, die einem helfen könnte, muss man immer überprüfen, ob sie aus einem Modul stammt, das man zuerst importieren muss. Wenn man das nicht macht, erhält man eine Fehlermeldung:

# %%
x = system()

print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-254fa572c185> in <module>
# ----> 1 x = system()
#       2
#       3 print(x)
#
# NameError: name 'system' is not defined

# %% [markdown]
# Erst nach dem Import des Modules `platform` kann die Funktion `system()` verwendet werden:

# %%
import platform

x = platform.system()

print(x)
# Out:
# Windows

# %% [markdown]
# Beim Import von Modulen können diese auch umbenannt werden (das sieht man häufig in Tutorials, dass bestimmte Module unter einer gängigen Abkürzung importiert werden):

# %%
import random as r

x = r.randint(1, 100)

print(x)
# Out:
# 39

# %% [markdown]
# Es gibt auch die Möglichkeit, von einem Modul nur eine bestimmte Funktion zu importieren und diese Funktion dann ohne den davorgestellten Modulnahmen zu verwenden:

# %%
from random import randint

x = randint(1, 100)

print(x)
# Out:
# 5

# %% [markdown]
# <div id="Aufgabe1" style="margin:0px; padding:10px; border-style:solid; border-width:2px; border-color:green;">
#
# <img src="img/dumbbell.png" style="float:right; width:100px">
#
# <span style="padding:5px; border-radius:5px; background-color:green; color:white">Aufgabe</span>
#
# Suche mit Hilfe des Internets ein Modul, welches eine Funktion zur Verfügung stellt, um das aktuelle Datum und die Uhrzeit auszugeben. Importiere dieses Modul und nutze die entsprechende Funktion.
#
# Hinweis: Das zu verwendende Modul ist etwas irritierend, weil der Name des Moduls gleich lautet wie das zu verwendende Objekt im Modul mit den entsprechenden Funktionen, man muss also beim Aufruf der Funktion zweimal das gleiche "Wort" davor anhängen...
#
# </div>

# %%
# Beginn eigener Code

import datetime

x = datetime.datetime.now()

print(x)

# Ende eigener Code
# Out:
# 2021-11-24 17:02:12.086197

# %% [markdown]
# ***

# %% [markdown]
# ## Ein eigenes Modul erstellen
#
# Ein eigenes Modul kann ganz einfach erstellt werden, indem Python Code in einem File mit der Endung `.py` gespeichert wird. Der Inhalt dieses Files kann dann als Modul eingebunden werden. Solche lokalen Module werden üblicherweise in einem separaten Ordner gespeichert. Um auf Module aus einem Ordner zugreifen zu können, muss der Ordnername beim Import (und bei der Nutzung des Moduls) mit einem Punkt `.` abgetrennt vorangestellt werden. Somit benennt man solche Module beim Import am besten gleich um, damit einfacher damit gearbeitet werden kann.

# %% [markdown]
# <div id="Aufgabe2" style="margin:0px; padding:10px; border-style:solid; border-width:2px; border-color:green;">
#
# <img src="img/dumbbell.png" style="float:right; width:100px">
#
# <span style="padding:5px; border-radius:5px; background-color:green; color:white">Aufgabe</span>
#
# Importiere das lokal erstellte Modul 'happy_greetings' aus dem Ornder 'lib' unter dem Namen `hg`. Lass Dir die verfügbaren Möglichkeiten anzeigen und nutze die Funktion `nice_greeting()` aus dem Modul.
# </div>

# %%
# Beginn eigener Code

import lib.happy_greetings as hg

print(dir(hg))

hg.nice_greeting()

# Ende eigener Code
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'my_greetings', 'nice_greeting', 'random']
# Ich wünsche Dir einen sensationellen Tag!

# %% [markdown]
# ***

# %% [markdown]
# # Arbeiten mit Dateien
#
# Eine wichtige Aufgabe beim Programmieren besteht darin, Daten aus Dateien einzulesen, um mit diesen dann weiterzuarbeiten. Nach einer Datenberarbeitung braucht es dann schlussendlich auch wieder die Möglichkeit, Daten in eine Datei zu schreiben (bspw. als Resultatdatei).
#
# ## Dateien einlesen
#
# Beim Arbeiten mit Dateien kann einiges schief gehen, deshalb ist es wichtig, darauf vorbereitet zu sein, dass etwas nicht klappt. Beispielsweise möchte man aus einer Datei lesen, die gar nicht existiert. Python hilft uns dabei:

# %%
with open('data/my_text.txt', "rt") as file:
    data = file.read()
    print(data)
# Out:
# Tiefe Weisheiten kommen dank Python ans Licht. Lass dir gesagt sein:
# Sei gut zu Dir!
# Und noch komplexer:
# Mach Dir keinen Stress!

# %% [markdown]
# Das Schlüsselwort `with` hilft uns beim Handling von Dateien. Es ist grundsätzlich nicht nötig, vereinfacht den Umgang mit Dateien aber (bspw. müssen Dateien nicht "geschlossen" werden oder bei einem Fehler werden keine "korrupten" Dateien erzeugt). Wer mehr zu `with` erfahren möchte, kann das in der [offiziellen Python Dokumentation](https://docs.python.org/3/reference/compound_stmts.html#the-with-statement) finden.
#
# Der erste Parameter von `open()` gibt dabei den Dateinamen (und den Pfad relativ vom Jupyter Notebook aus) der Datei an, der zweite Parameter bestimmt, wie mit der Datei gearbeitet werden soll, die wichtigsten Möglichkeiten sind:
#
# * 'r' steht für 'read', also aus der Datei lesen
# * 'w' steht für 'write', also eine Datei schreiben (Datei wird erstellt, falls sie noch nicht existiert und ansonsten überschrieben)
#
# Zusätzlich können die Files mit 't' im Text Modus bearbeitet werden oder mit 'b' im Binär Modus (vor allem für Bilddaten interessant). Falls kein Parameter angegeben wird, wählt `open()` den Modus 'rt', also als Textdatei lesen.
#
# Soll eine Datei zeilenweise eingelesen werden, kann mit Hilfe einer For Schleife durch das File iteriert werden:

# %%
with open('data/my_text.txt') as file:
    for line in file:
        print("Quatsch:", line)
# Out:
# Quatsch: Tiefe Weisheiten kommen dank Python ans Licht. Lass dir gesagt sein:
#
# Quatsch: Sei gut zu Dir!
#
# Quatsch: Und noch komplexer:
#
# Quatsch: Mach Dir keinen Stress!

# %% [markdown]
# <div id="Aufgabe3" style="margin:0px; padding:10px; border-style:solid; border-width:2px; border-color:green;">
#
# <img src="img/dumbbell.png" style="float:right; width:100px">
#
# <span style="padding:5px; border-radius:5px; background-color:green; color:white">Aufgabe</span>
#
# Summiere die Zahlen im File 'data/numbers.txt' auf und gib das Resultat aus.
#
# Hinweis: Die Zahlen werden aus dem Textfile als Text eingelesen. Denk daran, dass diese noch in ein Integer umgewandelt werden müssen.
# </div>

# %%
# Beginn eigener Code

with open("data/numbers.txt") as file:
    total = 0
    for number in file:
        total += int(number)
    print(total)
    
# Ende eigener Code
# Out:
# 49459

# %% [markdown]
# ***

# %% [markdown]
# ## Arbeiten mit CSV Dateien
#
# CSV (comma separated values) sind eine Möglichkeit, tabellarische Daten in einer Textdatei zu speichern. Beim Öffnen von CSV Dateien in Jupyter Lab über den File Browser (Ordner Sybmol in der linken Tableiste)  wie bspw. `data/population.csv` wird automatisch eine "tabellarische" Darstellung erzeugt. Wenn man die "Rohdaten" anschauen möchte, muss man im File Browser auf die Datei rechtsklicken und 'Open With/Editor' wählen.
#
# ## CSV als Liste einlesen und in ein Dictionary verwandeln

# %%
import csv

with open('data/population.csv') as file:
    csv_lists = list(csv.reader(file, delimiter=','))
    print(csv_lists)
# Out:
# [['country', 'population'], ['China', ' 1439323776'], ['Russia', ' 145934462'], ['Myanmar', ' 54409800'], ['Afghanistan', ' 38928346']]

# %% [markdown]
# Um die Funktion `reader()` zu verwenden, müssen wir zuerst das Modul 'csv' importieren. Die Funktion `reader()` braucht ein File (das wir mit `open()` geöffnet haben) und die Bezeichnung, welches Zeichen als Elementtrenner verwendet wurde (hier ein Komma ','). Wenn wir das Resultat von `reader()` noch mit Hilfe der Funktion `list()` in eine Liste umwandeln haben wir eine Liste von Listen erzeugt (jede Zeile ist eine Liste geworden und alle Zeilen landen ebenfalls in einer Liste). Die Arbeit damit ist etwas umständlich. Etwas besser geht es mit einem Dictionary:

# %%
country_pop = dict()

for row in csv_lists[1:]:
    country_pop[row[0]] = int(row[1])

print(country_pop["China"])
# Out:
# 1439323776

# %% [markdown]
# Hier iterieren wir die Liste `csv_lists` erst vom zweiten Eintrag an mit `[1:]` (der erste ist ja die Liste mit 'country' und 'population', das brauchen wir nicht mehr). Dann fügen wir zum Dictionary jeweils einen Eintrag mit dem Schlüssel, der an erster Stelle der Subliste steht, hinzu.
#
# Wir werden in den nächsten Lektionen viel mächtigere Werkzeuge kennen lernen (NumPy, Pandas), um mit strukturierten Daten zu arbeiten.

# %% [markdown]
# # JSON
#
# JSON (JavaScript Object Notation) ist ein Datenformat, das sich für "verschachtelte"  Daten eignet. Im Englischen spricht man von sogenannten "nested" Daten. Obwohl der Namen JSON auf JavaScript hinweist, hat sich JSON als Datenformat weit über JavaScript hinaus verbreitet und so bietet auch Python gute Möglichkeiten, um mit JSON zu arbeiten.
#
# ## Unterschiede CSV zu JSON
#
# Bei CSV Daten müssen alle Datensätze ins gleiche tabellarische Schema passen (sogenannte flat data), also beispielsweise für jedes Land muss ein Eintrag zur Bevölkerungszahl existieren. Wenn wir aber für verschiedene Länder verschiedene Daten speichern wollen, dann eignet sich JSON viel besser als CSV, weil es uns erlaubt, für verschiedene "Datenpunkte" verschiedene Angaben zu hinterlegen.

# %% [markdown]
# <div id="Aufgabe4" style="margin:0px; padding:10px; border-style:solid; border-width:2px; border-color:green;">
#
# <img src="img/dumbbell.png" style="float:right; width:100px">
#
# <span style="padding:5px; border-radius:5px; background-color:green; color:white">Aufgabe</span>
#
# Öffne das File [data/substances.json](data/substances.json) in Jupyter Lab (klick auf den Link). Schau Dir das Dokument an und öffne es nochmals mit einem Rechtsklick auf das Dokument im 'File Browser' (Ordner Symbol ganz links) und der Option 'Open Width/Editor'. In der Standard-Ansicht zeigt Jupyter Lab das JSON schon formatiert an (die kleinen Dreiecke erlauben, die unterliegenden Daten anzusehen). In der Editor Ansicht sehen wir den "Quelltext".
#
# Frage 1: Wieso würden sich die im JSON dargestellten Daten nicht gut für ein CSV eignen?
#
# Frage 2: Welche Datenstruktur in Python ist am ehesten mit einem JSON vergleichbar?
# </div>

# %% [markdown]
# ***

# %% [markdown]
# ## JSON Files in Python öffnen
#
# JSON Files können in Python einfach als Liste resp. Dictionary (oder Kombination von Liste und Dictionary) geöffnet werden. Dafür müssen wir zuerst wie schon gelernt das File in Python einlesen und dann diese eingelesenen Daten mit Hilfe der Funktion `load()` aus dem Modul `json` umwandeln.

# %% [markdown]
# <div id="Aufgabe5" style="margin:0px; padding:10px; border-style:solid; border-width:2px; border-color:green;">
#
# <img src="img/dumbbell.png" style="float:right; width:100px">
#
# <span style="padding:5px; border-radius:5px; background-color:green; color:white">Aufgabe</span>
#
# Lies das File 'data/substances.json' als Liste resp. Dictionary in Python ein und gib es mit dem `print()` Befehl wieder aus.
#
# </div>

# %%
import json

# Beginn eigener Code

with open("data/substances.json") as file:
    substances = json.load(file)
        
    print(substances)
    
# Ende eigener Code
# Out:
# [{'name': 'REGN-COV2', 'manufacturer': 'Roche', 'type': 'antibody drug', 'authorisation': False, 'approval_process': 'phase_II/III', 'dosage': 'not yet known'}, {'name': 'Spikevax', 'manufacturer': 'Moderna', 'type': 'vaccination', 'subtype': 'mRNA vaccination', 'authorisation': True, 'dosage': {'no_of_doses_required': 2, 'time_between': 30, 'booster_possible': True}}, {'name': 'Driponin', 'active_substances': ['Ivermectin', 'Butylhydroxyanisole'], 'manufacturer': 'Infectopharm', 'type': 'medication', 'authorisation': {'parasite infestation': True, 'COVID-19': False}}]

# %% [markdown]
# ***

# %% [markdown]
# ## Kombination von Listen und Dictionaries
#
# Die Kombination von Listen und Dictionaries (bspw. eingelesen aus dem obigen JSON File) ist sehr mächtig. Auf den ersten Blick sind solche Konstrukte aber etwas schwer zu durchschauen. Man muss jeweils genau wissen, innerhalb welcher Hierarchiestruktur man sich gerade befindet, siehe nochmals obiges Beispiel:
#
# ```JSON
# [
#     {
#         "name": "REGN-COV2",
#         "manufacturer": "Roche",
#         "type": "antibody drug",
#         "authorisation": false,
#         "approval_process": "phase_II/III",
#         "dosage": "not yet known"
#     },
#     {
#         "name": "Spikevax",
#         "manufacturer": "Moderna",
#         "type": "vaccination",
#         "subtype": "mRNA vaccination",
#         "authorisation": true,
#         "dosage": {
#             "no_of_doses_required": 2,
#             "time_between": 30,
#             "booster_possible": true
#         }
#     },
#     {
#         "name": "Driponin",
#         "active_substances": ["Ivermectin", "Butylhydroxyanisole"],
#         "manufacturer": "Infectopharm",
#         "type": "medication",
#         "authorisation": {
#             "parasite infestation": true,
#             "COVID-19": false
#         }
#     }
# ]
# ```
#
# Bei diesem JSON ist die oberste Ebene eine Liste (sieht man an den eckigen Klammern `[]`. Wenn man also dieses JSON in Python einliest und unter einer Variable speichert, kann man über `variablenname[index]` auf die einzelnen "Substanzen" zugreifen oder in einer For Schleife iterieren. Die einzelnen Listenelemente sind dann ein Dictionary (sieht man an den geschweiften Klammern `{}`) mit Schlüssel Wert Paaren. Teilweise sind dann diese Werte wiederum ein Dictionary oder eine Liste. Die Konstruktion "Liste aus Dictionaries" sieht man häufig, wenn bestimmte gleichartige Objekte, welche gut durch ein Dictionary beschrieben werden können, zusammengefasst werden sollen. Hier: Eine Sammlung von medizinischen Substanzen.

# %% [markdown]
# <div id="Aufgabe6" style="margin:0px; padding:10px; border-style:solid; border-width:2px; border-color:green;">
#
# <img src="img/dumbbell.png" style="float:right; width:100px">
#
# <span style="padding:5px; border-radius:5px; background-color:green; color:white">Aufgabe</span>
#
# Lies das File 'data/substances.json' wie in der obigen Aufgabe als Dictionary in Python ein. Häufig möchte man die Werte eines Schlüssels aus allen Listenelementen herauslesen: Erzeuge deshalb mit Hilfe einer List Comprehension eine Liste mit allen Namen der Hersteller der Substanzen.
#
# </div>

# %%
import json

# Beginn eigener Code

with open("data/substances.json") as file:
    substances = json.load(file)
        
    manufacturers = [substance["manufacturer"] for substance in substances]
    
    print(manufacturers)
    
# Ende eigener Code
# Out:
# ['Roche', 'Moderna', 'Infectopharm']

# %% [markdown]
# ***

# %% [markdown]
# ## JSON Daten von einer API einlesen
#
# Verschiedene Web APIs (Application Programming Interface) stellen Daten in einem JSON Format zur Verfügung. Die meisten dieser APIs benötigen eine Authentifizierung, um Daten zu beziehen, es gibt aber auch solche, die frei verfügbar sind. Um Daten von einer API zu lesen, dient die Funktion `get()` aus dem Modul `requests`, welche auch über eine integrierte Funktion verfügt, um die JSON Daten in ein Dicitonary umzuwandeln:

# %%
import requests

response = requests.get("http://api.open-notify.org/astros.json").json()

print(response)
# Out:
# {'message': 'success', 'people': [{'name': 'Mark Vande Hei', 'craft': 'ISS'}, {'name': 'Pyotr Dubrov', 'craft': 'ISS'}, {'name': 'Anton Shkaplerov', 'craft': 'ISS'}, {'name': 'Zhai Zhigang', 'craft': 'Shenzhou 13'}, {'name': 'Wang Yaping', 'craft': 'Shenzhou 13'}, {'name': 'Ye Guangfu', 'craft': 'Shenzhou 13'}, {'name': 'Raja Chari', 'craft': 'ISS'}, {'name': 'Tom Marshburn', 'craft': 'ISS'}, {'name': 'Kayla Barron', 'craft': 'ISS'}, {'name': 'Matthias Maurer', 'craft': 'ISS'}], 'number': 10}

# %% [markdown]
# Die oben kontaktierte API sendet ein JSON mit Informationen (Name und Raumfahrzeug) zu allen sich momentan im All befindenden Astronautinnen und Astronauten. Hier sehen wir ein Beispiel, dass Methoden (also Funktionen eines Objekts) sich auch aneinanderreihen lassen. Das kann man sich so vorstellen, dass die Funktion am linken Rand (hier `get()`) zuerst ausgeführt wird und auf das Resultat wird gleich die nächste Funktion (hier `json()`) angewandt.

# %% [markdown]
# # Schlussaufgabe
#
# <div id="Aufgabe7" style="margin:0px; padding:10px; border-style:solid; border-width:2px; border-color:green;">
#
# <img src="img/dumbbell.png" style="float:right; width:100px">
#
# <span style="padding:5px; border-radius:5px; background-color:green; color:white">Aufgabe</span>
#
# Erstelle mit Hilfe der API unter http://api.open-notify.org/astros.json ein Dictionary `crafts` mit allen bemannten Raumfahrzeugen und ihrer momentanen Besatzungsgrösse. Als Schlüssel soll also der Name des Raumfahrzeuges dienen und als Wert die Anzahl Austronaut:innen des Raumfahrzeuges.
#
# Hinweise: Das JSON, welches die API zurückliefert ist ein Dictionary, welches unter dem Schlüssel 'people' eine Liste mit Dictionaries der Astronaut:innen enthält. Iteriere die Liste 'people' durch und prüfe für jedes Raumfahrzeug, ob schon ein Eintrag im Dictionary `crafts` vorhanden ist. Falls nein, erstelle einen Eintrag und teile die Besatzungsgrösse 1 zu, falls ja, erhöhe die entsprechende Besatzungsgrösse um 1.
#
# </div>

# %%
import requests

response = requests.get("http://api.open-notify.org/astros.json").json()

crafts = {}

# Beginn eigener Code

for person in response['people']:
    if person['craft'] not in crafts:
        crafts[person['craft']] = 1
    else:
        crafts[person['craft']] += 1

# Ende eigener Code

print(crafts)
# Out:
# {'ISS': 7, 'Shenzhou 13': 3}

# %% [markdown]
# ***

# %% [markdown]
# # Zusatzaufgabe für Interessierte
#
# Hinweis: Diese Aufgabe ist etwas aufwändiger, aber schon ziemlich nahe an einer konkreten sinnvollen Anwendung. Aufgaben dieser Komplexität sind nicht prüfungsrelevant - aber trotzdem interessant.
#
# <div id="Aufgabe8" style="margin:0px; padding:10px; border-style:solid; border-width:2px; border-color:green;">
#
# <img src="img/dumbbell.png" style="float:right; width:100px">
#
# <span style="padding:5px; border-radius:5px; background-color:green; color:white">Aufgabe</span>
#
# Lies die Schweizer Verfassung [data/verfassung.txt](data/verfassung.txt) als File ein und zähle die Vorkommnisse aller Wörter darin. Sortiere die Vorkommnisse aller Wörter gemäss deren Anzahl.
#
# Hinweise: Erstelle ähnlich der Schlussaufgabe ein Dictionary mit den individuellen Worten als Schlüssel und der Anzahl der Vorkommnisse als Wert. Bevor du die Worte zählst, entferne möglichst alle Satzzeichen aus dem Text. Für die Möglichkeit der Sortierung eines Dictionaries (anhand der Werte und nicht der Schlüssel) erkundigst du dich am besten im Internet.
# </div>

# %%
# Beginn eigener Code

with open('data/verfassung.txt', encoding="utf-8") as file:
    data = file.read()
    data = data.lower()
    data = data.replace(",", "").replace(".", "").replace(":", "")
    words = data.split()
    
    occurences = {}
    
    for word in words:
        if word not in occurences:
            occurences[word] = 1
        else:
            occurences[word] += 1
    
    sorted_keys = sorted(occurences, key=occurences.get, reverse=True)
    ordered_occurences = {}
    
    for key in sorted_keys:
        ordered_occurences[key] = occurences[key]
        print(key + ":", ordered_occurences[key])

# Ende eigener Code
# Out:
# der: 856
# die: 827
# und: 754
# art: 261
# des: 229
# 2: 225
# 1: 221
# den: 201
# von: 194
# bund: 183
# für: 166
# zu: 155
# in: 153
# kantone: 149
# das: 147
# oder: 146
# 3: 145
# er: 135
# auf: 133
# kann: 126
# über: 120
# werden: 113
# zur: 104
# ist: 98
# sie: 94
# sind: 90
# dem: 88
# nach: 87
# im: 80
# an: 75
# gesetz: 73
# eine: 70
# sowie: 70
# nicht: 68
# 4: 67
# mit: 65
# durch: 64
# vorschriften: 55
# bundesversammlung: 53
# bei: 50
# bundes: 50
# aufgaben: 49
# ein: 48
# aus: 46
# ihrer: 46
# b: 46
# a: 45
# sich: 44
# können: 44
# einer: 43
# erlässt: 43
# bundesrat: 42
# vom: 41
# ihre: 41
# absatz: 41
# wird: 40
# massnahmen: 38
# c: 37
# artikel: 37
# hat: 36
# recht: 34
# person: 34
# zum: 34
# kantonen: 34
# schutz: 32
# wenn: 31
# bis: 31
# volk: 31
# 5: 30
# insbesondere: 30
# jede: 29
# vor: 29
# so: 29
# einen: 27
# zwischen: 27
# rechte: 26
# schweiz: 26
# personen: 26
# eines: 26
# bundesverfassung: 25
# dass: 25
# zuständigkeiten: 25
# haben: 24
# grundsätze: 23
# es: 23
# als: 23
# d: 23
# anspruch: 22
# diese: 22
# gewährleistet: 22
# gesetzgebung: 22
# erfüllung: 21
# mittel: 21
# dürfen: 21
# erlassen: 21
# beiträge: 21
# bestimmungen: 20
# sicherheit: 20
# anderen: 20
# einem: 20
# vorsehen: 20
# dabei: 20
# abgabe: 20
# übergangsbestimmung: 20
# unter: 19
# sache: 19
# regelt: 19
# e: 19
# abschnitt: 19
# weitere: 19
# soweit: 18
# leistungen: 18
# nur: 17
# sorgt: 17
# deren: 17
# behörden: 17
# dafür: 17
# verträge: 17
# form: 17
# fest: 17
# buchstabe: 17
# darf: 16
# politischen: 16
# rahmen: 16
# keine: 16
# gegen: 16
# seiner: 16
# legt: 16
# prozent: 16
# um: 15
# trägt: 15
# initiative: 15
# mitglieder: 15
# invalidenversicherung: 15
# inkrafttreten: 15
# landes: 14
# fördert: 14
# kapitel: 14
# andere: 14
# sorgen: 14
# allen: 14
# organisation: 14
# dieser: 14
# trifft: 14
# annahme: 14
# bundesrates: 14
# folgende: 13
# 6: 13
# interessen: 13
# verfahren: 13
# kantonalen: 13
# welche: 13
# ausland: 13
# muss: 12
# ihren: 12
# jeder: 12
# forschung: 12
# mehr: 12
# jahren: 12
# 18: 11
# freiheit: 11
# seine: 11
# alle: 11
# öffentlichen: 11
# grundsatz: 11
# wegen: 11
# wahrung: 11
# ihr: 11
# förderung: 11
# entscheidet: 11
# kindern: 11
# höchstens: 11
# f: 11
# kraft: 11
# rücksicht: 11
# zuständig: 11
# ab: 11
# bestimmt: 11
# fonds: 11
# hinterlassenen-: 11
# abstimmung: 11
# unterbreitet: 11
# räte: 11
# erhaltung: 10
# namentlich: 10
# 10: 10
# ausnahmen: 10
# besonderen: 10
# richterliche: 10
# bundesgericht: 10
# müssen: 10
# kanton: 10
# beziehungen: 10
# kosten: 10
# rechnung: 10
# verbrauchssteuer: 10
# mindestens: 10
# übertragen: 9
# sein: 9
# nimmt: 9
# 20: 9
# wirtschaftsfreiheit: 9
# ausübung: 9
# arbeitnehmerinnen: 9
# ausgenommen: 9
# ausländerinnen: 9
# drei: 9
# unterstützen: 9
# angemessenen: 9
# g: 9
# unterstützt: 9
# stehen: 9
# umsetzung: 9
# ausreichende: 9
# ständen: 9
# verkehr: 9
# dauer: 9
# befugnisse: 9
# fördern: 9
# wirtschaft: 9
# abgaben: 9
# erheben: 9
# angemessen: 9
# zusammenhang: 9
# finanzierung: 9
# totalrevision: 9
# teilrevision: 9
# bundesverwaltung: 9
# dezember: 9
# t: 9
# am: 8
# schweizerische: 8
# schützt: 8
# gemeinsame: 8
# entwicklung: 8
# interesse: 8
# menschen: 8
# niemand: 8
# alters: 8
# ausbildung: 8
# gesundheit: 8
# anderer: 8
# schweizer: 8
# behörde: 8
# arbeitnehmer: 8
# organisationen: 8
# streitigkeiten: 8
# auch: 8
# eidgenössischen: 8
# gemeinden: 8
# institutionen: 8
# mehrheit: 8
# bereich: 8
# armee: 8
# harmonisierung: 8
# hochschulen: 8
# tragen: 8
# berücksichtigt: 8
# nationalstrassen: 8
# reinertrag: 8
# 131: 8
# ausser: 8
# zwei: 8
# jahr: 8
# vorsorge: 8
# berufliche: 8
# neue: 8
# satz: 8
# stände: 8
# beiden: 8
# angenommen: 8
# schweizerischen: 7
# 7: 7
# unabhängigkeit: 7
# vielfalt: 7
# allgemeine: 7
# bilden: 7
# natürlichen: 7
# grundrechte: 7
# 8: 7
# familie: 7
# gilt: 7
# jugendlichen: 7
# 12: 7
# hilfe: 7
# beurteilung: 7
# innert: 7
# dieses: 7
# zudem: 7
# leisten: 7
# pflege: 7
# bestimmte: 7
# beachtet: 7
# folgenden: 7
# erklären: 7
# bevölkerung: 7
# diesen: 7
# obligatorisch: 7
# erhebt: 7
# umwelt: 7
# vollzug: 7
# landesgegenden: 7
# strassenverkehr: 7
# 86: 7
# flugtreibstoffen: 7
# je: 7
# hälfte: 7
# spezialfinanzierung: 7
# gemäss: 7
# steuer: 7
# jahre: 7
# referendum: 7
# tritt: 7
# innerhalb: 7
# bundesgerichts: 7
# –: 7
# fahrzeuge: 7
# verantwortung: 6
# verfassung: 6
# titel: 6
# appenzell: 6
# zweck: 6
# wahrt: 6
# inneren: 6
# setzt: 6
# staatlichen: 6
# gleichen: 6
# darauf: 6
# allgemein: 6
# wahl: 6
# zugang: 6
# arbeitgeberinnen: 6
# betreffen: 6
# gericht: 6
# machen: 6
# richter: 6
# einschränkungen: 6
# bedürfen: 6
# setzen: 6
# angemessene: 6
# grundversorgung: 6
# bundesrechts: 6
# ziele: 6
# einrichtungen: 6
# interkantonale: 6
# eingliederung: 6
# bundesbeschlusses: 6
# auswirkungen: 6
# gebiet: 6
# bildung: 6
# sicher: 6
# aufwendungen: 6
# berücksichtigen: 6
# anteil: 6
# sicherung: 6
# dessen: 6
# verwendet: 6
# finanziert: 6
# reinertrags: 6
# treibstoffen: 6
# 87a: 6
# eisenbahninfrastruktur: 6
# allgemeinen: 6
# einzelheiten: 6
# luftverkehr: 6
# geld-: 6
# landwirtschaft: 6
# alters-: 6
# aufenthalt: 6
# völkerrechtlichen: 6
# besteuerung: 6
# bundesgesetzes: 6
# volksinitiative: 6
# dringlich: 6
# jahres: 6
# gewählt: 6
# bundesgesetz: 6
# übergangsbestimmungen: 6
# abs: 6
# eidgenossenschaft: 5
# einheit: 5
# leben: 5
# frei: 5
# wer: 5
# volkes: 5
# ordnung: 5
# organe: 5
# staat: 5
# gesellschaft: 5
# bürgerrechte: 5
# stellung: 5
# arbeit: 5
# 9: 5
# organen: 5
# mensch: 5
# verboten: 5
# kinder: 5
# beizutreten: 5
# radio: 5
# fernsehen: 5
# 19: 5
# schweizerinnen: 5
# jedem: 5
# wahren: 5
# frist: 5
# erforderlichen: 5
# beurteilt: 5
# 31: 5
# selbst: 5
# fällen: 5
# ob: 5
# wie: 5
# nehmen: 5
# 35: 5
# dazu: 5
# privaten: 5
# grundrechten: 5
# anderes: 5
# ausländern: 5
# angelegenheiten: 5
# ersatzdienst: 5
# unterstützung: 5
# bestimmen: 5
# offen: 5
# zusammen: 5
# mitwirkung: 5
# diesem: 5
# notwendigen: 5
# verfügen: 5
# gemeinsam: 5
# vertrag: 5
# genehmigt: 5
# allgemeinverbindlicherklärung: 5
# betroffenen: 5
# einsatz: 5
# verlieren: 5
# übernehmen: 5
# stellen: 5
# untersteht: 5
# weiterbildung: 5
# solche: 5
# nutzung: 5
# arbeitet: 5
# wasser: 5
# bundesgesetzgebung: 5
# natur-: 5
# öffentliche: 5
# bedeutung: 5
# strassen: 5
# benützung: 5
# ganz: 5
# teilweise: 5
# zugewiesen: 5
# beträgt: 5
# franken: 5
# einzelnen: 5
# versicherten: 5
# erhalten: 5
# nötigenfalls: 5
# erklärt: 5
# ausgaben: 5
# beitritt: 5
# erbgut: 5
# 121: 5
# steuern: 5
# dies: 5
# vorlage: 5
# gegenentwurf: 5
# vorlagen: 5
# nationalrat: 5
# nationalrates: 5
# kommissionen: 5
# verordnungen: 5
# 2000: 5
# möglichst: 4
# staatliche: 4
# beachten: 4
# sprache: 4
# frau: 4
# sieht: 4
# behinderten: 4
# unversehrtheit: 4
# denen: 4
# werden;: 4
# ihres: 4
# bedingungen: 4
# post-: 4
# folgen: 4
# informationen: 4
# grundschulunterricht: 4
# vereinigungen: 4
# ihrem: 4
# ihm: 4
# arbeitgeber: 4
# möglichkeit: 4
# verhandlung: 4
# angemessener: 4
# parteien: 4
# ausserdem: 4
# untersagt: 4
# weise: 4
# angehörigen: 4
# umfassend: 4
# politische: 4
# willensbildung: 4
# gesetzlichen: 4
# erteilt: 4
# regeln: 4
# ausüben: 4
# niederlassung: 4
# militär-: 4
# geschützt: 4
# können;: 4
# verhältnis: 4
# einander: 4
# wirken: 4
# bundesrecht: 4
# interkantonalen: 4
# sofern: 4
# worden: 4
# verpflichten: 4
# straf-: 4
# erfolgt: 4
# einhaltung: 4
# besondere: 4
# kantonsverfassungen: 4
# verlangt: 4
# änderungen: 4
# vorbereitung: 4
# internationalen: 4
# abschluss: 4
# koordinieren: 4
# verpflichtet: 4
# freiwillig: 4
# noch: 4
# kultur: 4
# qualität: 4
# anerkennung: 4
# steht: 4
# schulen: 4
# längstens: 4
# koordination: 4
# aufgabenteilung: 4
# bereichen: 4
# abhängig: 4
# kriterien: 4
# gewähren: 4
# bestrebungen: 4
# zusammensetzung: 4
# treffen: 4
# bau: 4
# raumplanung: 4
# grund: 4
# 75b: 4
# wasservorkommen: 4
# arten: 4
# bisherigen: 4
# dienen: 4
# verwendung: 4
# errichtung: 4
# gedeckt: 4
# oberaufsicht: 4
# erhöht: 4
# bemessung: 4
# millionen: 4
# sind;: 4
# ertrag: 4
# direkten: 4
# personen;: 4
# energie: 4
# wirtschaftliche: 4
# 95: 4
# ausserhalb: 4
# 100: 4
# bekämpfung: 4
# abweichen: 4
# versorgung: 4
# schweren: 4
# richtet: 4
# lebensmitteln: 4
# umgang: 4
# geldspiele: 4
# betrieb: 4
# tätigkeit: 4
# versicherung: 4
# erster: 4
# verwenden: 4
# versichern: 4
# ihnen: 4
# einzelne: 4
# berücksichtigung: 4
# jedes: 4
# gentechnologie: 4
# beim: 4
# 121a: 4
# vorsieht: 4
# gutachten: 4
# ausgeschlossen: 4
# wichtigen: 4
# gegenstand: 4
# fallen: 4
# finanzausgleichs: 4
# stempelsteuer: 4
# lastenausgleich: 4
# volksinitiativen: 4
# stimmberechtigte: 4
# seit: 4
# bundesgesetze: 4
# frage: 4
# genehmigungsbeschluss: 4
# richterinnen: 4
# bundeskanzler: 4
# vier: 4
# erlasse: 4
# besteht: 4
# ständerat: 4
# vorsitz: 4
# vizepräsidentin: 4
# verhandeln: 4
# wahlen: 4
# verordnung: 4
# befristen: 4
# eisenbahngrossprojekte: 4
# 2003: 4
# januar: 4
# ausführungsbestimmungen: 4
# gegenüber: 3
# achtung: 3
# geben: 3
# obwalden: 3
# nidwalden: 3
# basel-stadt: 3
# basel-landschaft: 3
# ausserrhoden: 3
# innerrhoden: 3
# kulturelle: 3
# lebensgrundlagen: 3
# gerechte: 3
# beschränkt: 3
# handeln: 3
# private: 3
# treu: 3
# glauben: 3
# staatlicher: 3
# sozialziele: 3
# menschenwürde: 3
# würde: 3
# achten: 3
# rechtsgleichheit: 3
# sozialen: 3
# allem: 3
# gleichwertige: 3
# ohne: 3
# behandelt: 3
# behandlung: 3
# 10a: 3
# öffentlich: 3
# dienstleistungen: 3
# 11: 3
# jugendliche: 3
# 13: 3
# daten: 3
# 15: 3
# wählen: 3
# anzugehören: 3
# meinungs-: 3
# versammlungen: 3
# tätigkeiten: 3
# beteiligen: 3
# ausgewiesen: 3
# 26: 3
# freie: 3
# erwerbstätigkeit: 3
# vermittlung: 3
# zulässig: 3
# verpflichtungen: 3
# bestimmten: 3
# 29: 3
# vorgesehenen: 3
# entzogen: 3
# unverzüglich: 3
# ganzen: 3
# gefahr: 3
# bürgerrecht: 3
# kantonale: 3
# erwerb: 3
# verlust: 3
# monaten: 3
# auslandschweizerinnen: 3
# pflichten: 3
# ergänzung: 3
# finden: 3
# arbeitslosigkeit: 3
# erfüllt: 3
# erfüllen: 3
# einheitlichen: 3
# regelung: 3
# nutzen: 3
# leistung: 3
# wirtschaftlich: 3
# massgabe: 3
# informiert: 3
# rechtzeitig: 3
# erreichen: 3
# belässt: 3
# finanziellen: 3
# schliessen: 3
# erlass: 3
# verträgen: 3
# 62: 3
# h: 3
# geht: 3
# bedarf: 3
# stimmberechtigten: 3
# bestand: 3
# zustimmung: 3
# wesentlichen: 3
# kommt: 3
# ausländischen: 3
# übrigen: 3
# anstrengungen: 3
# dient: 3
# land: 3
# zivilen: 3
# abwehr: 3
# weder: 3
# entschädigung: 3
# zusammenarbeit: 3
# aller: 3
# zuständigkeit: 3
# berufsbildung: 3
# betreibt: 3
# errichten: 3
# betreiben: 3
# weg: 3
# amtlicher: 3
# ausbildungsbeiträge: 3
# festlegen: 3
# ergreifen: 3
# sport: 3
# einwirkungen: 3
# erschliessung: 3
# eingriffe: 3
# 80: 3
# tiere: 3
# tieren: 3
# werke: 3
# schiene: 3
# übt: 3
# stellt: 3
# aufgabe: 3
# belastungen: 3
# pflanzen: 3
# 85: 3
# schwerverkehrsabgabe: 3
# neu: 3
# beiträgen: 3
# nötig: 3
# soll: 3
# statt: 3
# 130: 3
# einnahmen: 3
# zuschlag: 3
# energieverbrauch: 3
# unabhängigen: 3
# vorgelegt: 3
# wettbewerb: 3
# richten: 3
# in-: 3
# stimmt: 3
# wählt: 3
# unabhängige: 3
# stimmen: 3
# keinen: 3
# renten: 3
# buchstaben: 3
# missbräuchen: 3
# unternehmen: 3
# nationalbank: 3
# finanzen: 3
# direkte: 3
# gewährung: 3
# gewährt: 3
# fall: 3
# produktion: 3
# einkommen: 3
# landwirtschaftliche: 3
# verkauf: 3
# erforderlich: 3
# regionalen: 3
# zahl: 3
# vollumfänglich: 3
# mitgliedern: 3
# wohnungsbau: 3
# befreien: 3
# angepasst: 3
# wobei: 3
# gebrannten: 3
# ergänzungsleistungen: 3
# hause: 3
# gunsten: 3
# risiken: 3
# finanzielle: 3
# kranken-: 3
# unfallversicherung: 3
# persönlichkeit: 3
# erfordert: 3
# forschungsvorhaben: 3
# teilnehmenden: 3
# urteilsunfähigen: 3
# keim-: 3
# embryonen: 3
# ausländer: 3
# gesetzgeber: 3
# tatbestände: 3
# einreiseverbot: 3
# jährliche: 3
# höchstzahlen: 3
# messwesen: 3
# gerichte: 3
# nichts: 3
# öffentlichkeit: 3
# aufgehoben: 3
# höchstbetrag: 3
# voranschlag: 3
# gesamtausgaben: 3
# beschliesst: 3
# staatsrechnung: 3
# leistungsfähigkeit: 3
# mehrwertsteuer: 3
# normalsatz: 3
# verrechnungssteuer: 3
# finanz-: 3
# gestellt: 3
# 000: 3
# amtlichen: 3
# verlangen: 3
# anregung: 3
# völkerrechts: 3
# entsprechende: 3
# stichfrage: 3
# beide: 3
# standesstimmen: 3
# bundesverfassung;: 3
# völkerrechtliche: 3
# rechtsetzende: 3
# stimmenden: 3
# bundesbehörden: 3
# bundeskanzlerin: 3
# oberste: 3
# abgeordneten: 3
# vizepräsidenten: 3
# beschlüsse: 3
# jedoch: 3
# bundesbeschluss: 3
# äusseren: 3
# geschäfte: 3
# bundespräsidentin: 3
# bundespräsident: 3
# öffentlich-rechtlichen: 3
# revision: 3
# beschlossen: 3
# 650: 3
# bestimmung: 3
# während: 3
# juni: 3
# neugestaltung: 3
# zweiter: 3
# geltenden: 3
# 101: 2
# april: 2
# 1999: 2
# (stand: 2
# märz: 2
# schweizervolk: 2
# demokratie: 2
# welt: 2
# gemeinsamen: 2
# graubünden: 2
# tessin: 2
# wohlfahrt: 2
# nachhaltige: 2
# grosse: 2
# ist;: 2
# üben: 2
# landessprachen: 2
# deutsch: 2
# französisch: 2
# italienisch: 2
# handelns: 2
# grundlage: 2
# verhältnismässig: 2
# völkerrecht: 2
# subsidiarität: 2
# zuweisung: 2
# gesellschaftliche: 2
# selber: 2
# bewältigung: 2
# schützen: 2
# herkunft: 2
# geschlechts: 2
# überzeugung: 2
# körperlichen: 2
# geistigen: 2
# psychischen: 2
# mann: 2
# beseitigung: 2
# willkür: 2
# persönliche: 2
# folter: 2
# grausamer: 2
# unmenschlicher: 2
# bestrafung: 2
# verbot: 2
# verhüllung: 2
# eigenen: 2
# gesicht: 2
# raum: 2
# orten: 2
# verhüllen: 2
# grundsätzlich: 2
# angeboten: 2
# umfassen: 2
# gründe: 2
# notlagen: 2
# not: 2
# betreuung: 2
# wohnung: 2
# missbrauch: 2
# 14: 2
# ehe: 2
# glaubens-: 2
# gewissensfreiheit: 2
# allein: 2
# religionsgemeinschaft: 2
# religiösem: 2
# unterricht: 2
# gezwungen: 2
# 16: 2
# informationsfreiheit: 2
# verbreiten: 2
# 17: 2
# presse: 2
# formen: 2
# fernmeldetechnischen: 2
# verbreitung: 2
# darbietungen: 2
# sprachenfreiheit: 2
# ausreichenden: 2
# unentgeltlichen: 2
# wissenschaftlichen: 2
# 21: 2
# kunst: 2
# versammlungsfreiheit: 2
# fernzubleiben: 2
# 23: 2
# vereinigungsfreiheit: 2
# ort: 2
# 25: 2
# ausgeliefert: 2
# ausgeschafft: 2
# enteignung: 2
# entschädigt: 2
# freien: 2
# privatwirtschaftlichen: 2
# koalitionsfreiheit: 2
# streik: 2
# entgegenstehen: 2
# führen: 2
# verfügt: 2
# notwendig: 2
# ausschliessen: 2
# erhoben: 2
# freiheitsentzugs: 2
# unterrichtet: 2
# geltend: 2
# lassen: 2
# untersuchungshaft: 2
# richterin: 2
# gehalten: 2
# urteil: 2
# jederzeit: 2
# rasch: 2
# höheren: 2
# fälle: 2
# petitionen: 2
# kenntnis: 2
# verwirklichung: 2
# kommen: 2
# vorgesehen: 2
# anders: 2
# dritter: 2
# gemeinde: 2
# kantons: 2
# beteiligung: 2
# abstammung: 2
# einbürgerung: 2
# dritten: 2
# kommunalen: 2
# 40: 2
# auslandschweizer: 2
# sozialversicherungen: 2
# privater: 2
# familien: 2
# erwachsenen: 2
# gefördert: 2
# alter: 2
# aus-: 2
# selbstständigen: 2
# sozial: 2
# kulturellen: 2
# krankheit: 2
# streben: 2
# verfassungsmässigen: 2
# unmittelbaren: 2
# zuweist: 2
# übersteigen: 2
# gemeinwesen: 2
# arbeiten: 2
# schulden: 2
# rechtsetzung: 2
# holt: 2
# stellungnahmen: 2
# betroffen: 2
# 46: 2
# miteinander: 2
# besonderheiten: 2
# eigenständigkeit: 2
# eigene: 2
# rechten: 2
# zuwiderlaufen: 2
# bringen: 2
# rechtsetzender: 2
# ermächtigen: 2
# verbindlich: 2
# massnahmenvollzug;: 2
# schulwesen: 2
# i: 2
# voraussetzungen: 2
# vorrang: 2
# 50: 2
# gemeindeautonomie: 2
# rechts: 2
# agglomerationen: 2
# revidiert: 2
# gewährleistung: 2
# widersprechen: 2
# verfassungsmässige: 2
# betroffene: 2
# genehmigung: 2
# auswärtigen: 2
# entscheiden: 2
# besonderes: 2
# gewicht: 2
# zivilschutz: 2
# bedrohungen: 2
# militärdienst: 2
# veranlagt: 2
# eingezogen: 2
# ersatz: 2
# erwerbsausfalls: 2
# gesundheitlichen: 2
# schaden: 2
# erleiden: 2
# ausrüstung: 2
# gütern: 2
# schutzdienst: 2
# aufsicht: 2
# unentgeltlich: 2
# sonderschulung: 2
# altersjahr: 2
# koordinationsweg: 2
# abschlüssen: 2
# angebot: 2
# technischen: 2
# hochschulbereichs: 2
# qualitätssicherung: 2
# autonomie: 2
# unterschiedlichen: 2
# trägerschaften: 2
# besonders: 2
# wissenschaftliche: 2
# davon: 2
# sichergestellt: 2
# 65: 2
# zustand: 2
# führung: 2
# erhebungsaufwand: 2
# halten: 2
# ausrichtung: 2
# musikalische: 2
# sprachliche: 2
# amtssprachen: 2
# sprachgemeinschaften: 2
# kirche: 2
# natur: 2
# schädlichen: 2
# ihn: 2
# vorbehält: 2
# besiedlung: 2
# koordiniert: 2
# vermessung: 2
# zweitwohnungen: 2
# gewässer: 2
# anliegen: 2
# wald: 2
# waldes: 2
# heimatschutz: 2
# heimatschutzes: 2
# gesamtschweizerischer: 2
# tier-: 2
# lebensräume: 2
# bedrohte: 2
# moore: 2
# moorlandschaften: 2
# besonderer: 2
# anlagen: 2
# landwirtschaftlichen: 2
# fischerei: 2
# jagd: 2
# lebenden: 2
# tieren;: 2
# einfuhr: 2
# öffentlicher: 2
# seilbahnen: 2
# verkehrs: 2
# teil: 2
# bleiben: 2
# 83: 2
# strasseninfrastruktur: 2
# 84: 2
# alpengebiet: 2
# begrenzt: 2
# transitverkehr: 2
# grenze: 2
# näher: 2
# schwerverkehr: 2
# allgemeinheit: 2
# beteiligt: 2
# anhänger: 2
# unterstehen: 2
# verbesserung: 2
# e;: 2
# aber: 2
# pro: 2
# indexierung: 2
# erträge: 2
# nationalstrassennetz: 2
# umwelt-: 2
# macht;: 2
# gutgeschrieben: 2
# 87: 2
# drittel: 2
# ertrags: 2
# bundessteuer: 2
# 87b: 2
# hohen: 2
# fuss-: 2
# wander-: 2
# netze: 2
# energiepolitik: 2
# sparsamen: 2
# rationellen: 2
# energien: 2
# fahrzeugen: 2
# 90: 2
# kernenergie: 2
# transport: 2
# treibstoffe: 2
# fernmeldewesen: 2
# tarife: 2
# grundsätzen: 2
# festgelegt: 2
# bedürfnisse: 2
# wirtschaftlichen: 2
# kantonal: 2
# aktionärinnen: 2
# aktionäre: 2
# sinne: 2
# nachhaltigen: 2
# jährlich: 2
# verwaltungsrates: 2
# legen: 2
# organmitglieder: 2
# voraus: 2
# höhe: 2
# sechs: 2
# unlauteren: 2
# konsumentinnen: 2
# konsumenten: 2
# streitwertgrenze: 2
# währungspolitik: 2
# bundes;: 2
# führt: 2
# verwaltet: 2
# bildet: 2
# reserven: 2
# verhütung: 2
# teuerung: 2
# vorübergehend: 2
# bundesrechtlichen: 2
# freigabe: 2
# steuererleichterungen: 2
# 102: 2
# begegnen: 2
# 103: 2
# berufe: 2
# existenz: 2
# markt: 2
# ausgerichtete: 2
# bäuerlichen: 2
# chemikalien: 2
# beratung: 2
# schafft: 2
# grundlagen: 2
# land-: 2
# herstellung: 2
# spielbanken: 2
# absätze: 2
# anwendung: 2
# waffen: 2
# kriegsmaterial: 2
# beschaffung: 2
# wohnen: 2
# wohnungsbaus: 2
# verbilligung: 2
# betagten: 2
# mietwesen: 2
# allgemeinverbindlich: 2
# begründeten: 2
# minderheitsinteressen: 2
# verschiedenheiten: 2
# beeinträchtigen: 2
# 110: 2
# bundesfeiertag: 2
# invalidenvorsorge: 2
# beruflichen: 2
# selbstvorsorge: 2
# eidgenössische: 2
# steuerpflicht: 2
# abis: 2
# sachleistungen: 2
# existenzbedarf: 2
# betragen: 2
# umfang: 2
# 112b: 2
# invalider: 2
# 112c: 2
# gesamtschweizerische: 2
# 113: 2
# ermöglicht: 2
# obligatorisch;: 2
# selbstständigerwerbende: 2
# bezahlen: 2
# arbeitslosenversicherung: 2
# ausserordentlichen: 2
# 115: 2
# familienzulagen: 2
# mutterschaftsversicherung: 2
# familienausgleichskasse: 2
# versicherungsleistungen: 2
# bevölkerungsgruppen: 2
# medizinische: 2
# hausarztmedizin: 2
# bestandteil: 2
# organismen: 2
# gegenständen: 2
# gefährden: 2
# komplementärmedizin: 2
# ablehnung: 2
# forschungsvorhabens: 2
# erkenntnisse: 2
# überprüfung: 2
# ergeben: 2
# fortpflanzungsmedizin: 2
# menschlichem: 2
# menschlicher: 2
# unzulässig: 2
# keimgut: 2
# medizinisch: 2
# fortpflanzung: 2
# eizellen: 2
# körpers: 2
# erzeugnissen: 2
# kein: 2
# handel: 2
# geweben: 2
# zellen: 2
# menschlichen: 2
# 120: 2
# unabhängig: 2
# aufenthaltsrecht: 2
# rechtsansprüche: 2
# verurteilt: 2
# ergänzen: 2
# entsprechenden: 2
# bewilligungen: 2
# kontingente: 2
# gelten: 2
# gesuch: 2
# abgeschlossen: 2
# zivilrecht: 2
# strafrecht: 2
# rechtsprechung: 2
# massnahmenvollzug: 2
# sexual-: 2
# gewaltstraftäter: 2
# erstellt: 2
# verwahrung: 2
# erstellen: 2
# strafe: 2
# sexuellen: 2
# straftaten: 2
# pubertät: 2
# abhängigen: 2
# beeinträchtigt: 2
# straftat: 2
# 126: 2
# haushaltführung: 2
# ausserordentlichem: 2
# zahlungsbedarf: 2
# erhöhung: 2
# 159: 2
# kreis: 2
# 128: 2
# belastung: 2
# erfordern: 2
# steuersätze: 2
# steuerliche: 2
# reduzierten: 2
# prozentpunkt: 2
# prozentpunkte: 2
# 01: 2
# unterer: 2
# einkommensschichten: 2
# verbrauchssteuern: 2
# 2bis: 2
# urkunden: 2
# zölle: 2
# kantonaler: 2
# bezeichnet: 2
# ressourcen: 2
# ressourcenstarken: 2
# veröffentlichung: 2
# unterbreiten: 2
# ausgearbeiteten: 2
# entwurfs: 2
# verletzt: 2
# materie: 2
# gleichzeitig: 2
# welcher: 2
# falls: 2
# erzielt: 2
# angenommenen: 2
# verfassungsänderungen: 2
# volks-: 2
# prozentuale: 2
# erklärten: 2
# verfassungsgrundlage: 2
# geltungsdauer: 2
# übersteigt;: 2
# uneinigkeit: 2
# bundesbeschlüsse: 2
# vertrags: 2
# vertrages: 2
# aufnehmen: 2
# ergebnis: 2
# volksabstimmung: 2
# standesstimme: 2
# wählbar: 2
# unvereinbarkeiten: 2
# ständerates: 2
# amtsdauer: 2
# kammern: 2
# gesamterneuerung: 2
# verteilt: 2
# abgeordnete: 2
# geregelt: 2
# sessionen: 2
# regelmässig: 2
# einberufung: 2
# rates: 2
# rat: 2
# mitte: 2
# wiederwahl: 2
# fraktionen: 2
# parlamentsdienste: 2
# getrennt: 2
# stande: 2
# gültigkeit: 2
# vereinigte: 2
# zuständigkeitskonflikte: 2
# obersten: 2
# begnadigungen: 2
# sitzungen: 2
# räten: 2
# anpassen: 2
# initiativrecht: 2
# immunität: 2
# ausdehnen: 2
# gehören: 2
# rechte;: 2
# erklärtes: 2
# beaufsichtigt: 2
# träger: 2
# wirksamkeit: 2
# aufträge: 2
# zuständigkeitsbereich: 2
# einsprache: 2
# neutralität: 2
# aktivdienst: 2
# bietet: 2
# teile: 2
# departementen: 2
# bundeskanzlei: 2
# regierungspolitik: 2
# ermächtigt: 2
# verfügungen: 2
# unmittelbar: 2
# 4000: 2
# wo: 2
# durchführung: 2
# beschwerden: 2
# begründen: 2
# bestellt: 2
# zwingenden: 2
# 1998: 2
# zehn: 2
# motorfahrzeugen: 2
# anhängern: 2
# gesamtgewicht: 2
# verordnungsweg: 2
# fahrzeugkategorien: 2
# sonderregelungen: 2
# fahrten: 2
# grenzbereich: 2
# dadurch: 2
# immatrikulierte: 2
# besser: 2
# übertretungen: 2
# bussen: 2
# ziehen: 2
# inland: 2
# immatrikulierten: 2
# verzinsung: 2
# rückzahlung: 2
# bevorschussung: 2
# 2018: 2
# bleibt: 2
# befugnis: 2
# erhebung: 2
# ende: 2
# 2035: 2
# befristet: 2
# hebt: 2
# anhebung: 2
# vereinten: 2
# nationen: 2
# oktober: 2
# genehmigte: 2
# weiter: 2
# fünf: 2
# gentechnisch: 2
# veränderte: 2
# ausführungsgesetzgebung: 2
# mai: 2
# 1874: 2
# fragen: 2
# volksbegehren: 2
# vorziehe;: 2
# beschluss: 2
# 2021): 1
# präambel: 1
# namen: 1
# gottes: 1
# allmächtigen!: 1
# schöpfung: 1
# bestreben: 1
# erneuern: 1
# frieden: 1
# solidarität: 1
# offenheit: 1
# stärken: 1
# willen: 1
# gegenseitiger: 1
# rücksichtnahme: 1
# bewusstsein: 1
# errungenschaften: 1
# künftigen: 1
# generationen: 1
# gewiss: 1
# gebraucht: 1
# stärke: 1
# misst: 1
# wohl: 1
# schwachen: 1
# zürich: 1
# bern: 1
# luzern: 1
# uri: 1
# schwyz: 1
# glarus: 1
# zug: 1
# freiburg: 1
# solothurn: 1
# schaffhausen: 1
# st: 1
# gallen: 1
# aargau: 1
# thurgau: 1
# waadt: 1
# wallis: 1
# neuenburg: 1
# genf: 1
# jura: 1
# zusammenhalt: 1
# chancengleichheit: 1
# bürgerinnen: 1
# bürgern: 1
# dauerhafte: 1
# friedliche: 1
# internationale: 1
# souverän: 1
# souveränität: 1
# rätoromanisch: 1
# rechtsstaatlichen: 1
# schranke: 1
# staatliches: 1
# liegen: 1
# 5a: 1
# individuelle: 1
# wahr: 1
# kräften: 1
# gleich: 1
# diskriminiert: 1
# rasse: 1
# lebensform: 1
# religiösen: 1
# weltanschaulichen: 1
# behinderung: 1
# gleichberechtigt: 1
# rechtliche: 1
# tatsächliche: 1
# gleichstellung: 1
# lohn: 1
# benachteiligungen: 1
# todesstrafe: 1
# körperliche: 1
# geistige: 1
# bewegungsfreiheit: 1
# erniedrigender: 1
# gesichts*: 1
# zugänglich: 1
# jedermann: 1
# beanspruchbare: 1
# sakralstätten: 1
# zwingen: 1
# aufgrund: 1
# ausschliesslich: 1
# klimatischen: 1
# einheimischen: 1
# brauchtums: 1
# urteilsfähigkeit: 1
# gerät: 1
# lage: 1
# menschenwürdiges: 1
# dasein: 1
# unerlässlich: 1
# privatsphäre: 1
# privat-: 1
# familienlebens: 1
# brief-: 1
# fernmeldeverkehrs: 1
# persönlichen: 1
# religion: 1
# weltanschauliche: 1
# gemeinschaft: 1
# bekennen: 1
# religiöse: 1
# handlung: 1
# vorzunehmen: 1
# meinung: 1
# ungehindert: 1
# äussern: 1
# empfangen: 1
# zugänglichen: 1
# quellen: 1
# beschaffen: 1
# medienfreiheit: 1
# öffent-lichen: 1
# zensur: 1
# redaktionsgeheimnis: 1
# wissenschaftsfreiheit: 1
# lehre: 1
# kunstfreiheit: 1
# 22: 1
# organisieren: 1
# teilzunehmen: 1
# vereinigung: 1
# anzu-gehören: 1
# 24: 1
# niederlassungsfreiheit: 1
# niederzulassen: 1
# verlassen: 1
# einzureisen: 1
# ausweisung: 1
# auslieferung: 1
# ausschaffung: 1
# einverständnis: 1
# ausländische: 1
# flüchtlinge: 1
# verfolgt: 1
# droht: 1
# eigentumsgarantie: 1
# eigentum: 1
# enteignungen: 1
# eigentumsbeschränkungen: 1
# gleichkommen: 1
# voll: 1
# 27: 1
# umfasst: 1
# berufes: 1
# 28: 1
# zusammenzuschliessen: 1
# solchen: 1
# beizulegen: 1
# aussperrung: 1
# arbeitsbeziehungen: 1
# arbeitsfrieden: 1
# schlichtungsverhandlungen: 1
# kategorien: 1
# verbieten: 1
# verfahrensgarantien: 1
# gerichts-: 1
# verwaltungsinstanzen: 1
# gleiche: 1
# rechtliches: 1
# gehör: 1
# unentgeltliche: 1
# rechtspflege: 1
# rechtsbegehren: 1
# aussichtslos: 1
# erscheint: 1
# rechtsbeistand: 1
# 29a: 1
# rechtsweggarantie: 1
# rechtsstreitigkeiten: 1
# ausnahmefällen: 1
# 30: 1
# gerichtliche: 1
# gerichtlichen: 1
# geschaffenes: 1
# zuständiges: 1
# unabhängiges: 1
# unparteiisches: 1
# ausnahmegerichte: 1
# zivilklage: 1
# wohnsitzes: 1
# gerichtsstand: 1
# gerichtsverhandlung: 1
# urteilsverkündung: 1
# freiheitsentzug: 1
# vorgeschriebene: 1
# verständlichen: 1
# nächsten: 1
# benachrichtigen: 1
# genommen: 1
# vorgeführt: 1
# weiterhin: 1
# haft: 1
# freigelassen: 1
# anzurufen: 1
# möglich: 1
# rechtmässigkeit: 1
# 32: 1
# strafverfahren: 1
# rechtskräftigen: 1
# verurteilung: 1
# unschuldig: 1
# angeklagte: 1
# erhobenen: 1
# beschuldigungen: 1
# zustehenden: 1
# verteidigungsrechte: 1
# verurteilte: 1
# überprüfen: 1
# einzige: 1
# instanz: 1
# urteilt: 1
# 33: 1
# petitionsrecht: 1
# richten;: 1
# daraus: 1
# nachteile: 1
# erwachsen: 1
# 34: 1
# garantie: 1
# unverfälschte: 1
# stimmabgabe: 1
# rechtsordnung: 1
# geltung: 1
# wahrnimmt: 1
# gebunden: 1
# ver-pflichtet: 1
# beizutragen: 1
# eignen: 1
# wirksam: 1
# 36: 1
# schwerwiegende: 1
# ernster: 1
# unmittelbarer: 1
# abwendbarer: 1
# öffentliches: 1
# gerechtfertigt: 1
# kerngehalt: 1
# unantastbar: 1
# 37: 1
# schweizerbürgerin: 1
# schweizerbürger: 1
# besitzt: 1
# bevorzugt: 1
# benachteiligt: 1
# bürgergemeinden: 1
# korporationen: 1
# vermögen: 1
# sei: 1
# denn: 1
# sehe: 1
# etwas: 1
# 38: 1
# heirat: 1
# adoption: 1
# bürgerrechts: 1
# gründen: 1
# wiedereinbürgerung: 1
# mindestvorschriften: 1
# einbürgerungsbewilligung: 1
# erleichtert: 1
# ausländergeneration;: 1
# staatenlosen: 1
# 39: 1
# wohnsitz: 1
# ausgeübt: 1
# neuzugezogene: 1
# stimmrecht: 1
# erst: 1
# wartefrist: 1
# ausland-schweizer: 1
# untereinander: 1
# ziel: 1
# verfolgen: 1
# bezug: 1
# pflicht: 1
# 41: 1
# persönlicher: 1
# teilhat;: 1
# notwendige: 1
# erhält;: 1
# gemeinschaften: 1
# erwerbsfähige: 1
# lebensunterhalt: 1
# be-dingungen: 1
# bestreiten: 1
# wohnungssuchende: 1
# tragbaren: 1
# erwerbsfähigen: 1
# fähigkeiten: 1
# weiterbilden: 1
# verantwortlichen: 1
# integration: 1
# wirtschaft-lichen: 1
# invalidität: 1
# unfall: 1
# mutterschaft: 1
# verwaisung: 1
# verwitwung: 1
# gesichert: 1
# verfügbaren: 1
# sozialzielen: 1
# ansprüche: 1
# lei-stungen: 1
# abgeleitet: 1
# 42: 1
# 43: 1
# 43a: 1
# übernimmt: 1
# anfällt: 1
# vergleichbarer: 1
# bedarfsgerecht: 1
# zusammenwirken: 1
# 44: 1
# beistand: 1
# amts-: 1
# rechtshilfe: 1
# beigelegt: 1
# 45: 1
# vorhaben;: 1
# vereinbaren: 1
# programme: 1
# ausführen: 1
# finanziell: 1
# gestaltungsfreiheit: 1
# 47: 1
# ausreichend: 1
# organisationsautonomie: 1
# finanzierungsquellen: 1
# 48: 1
# schaffen: 1
# regionalem: 1
# wahrnehmen: 1
# umsetzen: 1
# inhaltlichen: 1
# grundzüge: 1
# festlegt: 1
# 48a: 1
# beteiligungspflicht: 1
# antrag: 1
# interessierter: 1
# aufgabenbereichen: 1
# hinsichtlich: 1
# genannten: 1
# bereiche;: 1
# hochschulen;: 1
# kultureinrichtungen: 1
# überregionaler: 1
# bedeutung;: 1
# abfallbewirtschaftung;: 1
# abwasserreinigung;: 1
# agglomerationsverkehr;: 1
# spitzenmedizin: 1
# spezialkliniken;: 1
# invaliden: 1
# beteiligungsverpflichtung: 1
# 49: 1
# entgegenstehendem: 1
# kantonalem: 1
# wacht: 1
# seinem: 1
# möglichen: 1
# situation: 1
# städte: 1
# berggebiete: 1
# bundesgarantien: 1
# 51: 1
# gibt: 1
# demokratische: 1
# zustim-mung: 1
# 52: 1
# greift: 1
# gestört: 1
# bedroht: 1
# 53: 1
# gebietsveränderungen: 1
# grenzbereinigungen: 1
# vornehmen: 1
# 54: 1
# auswärtige: 1
# wohlfahrt;: 1
# linderung: 1
# armut: 1
# menschenrechte: 1
# friedlichen: 1
# zusammenleben: 1
# völker: 1
# 55: 1
# aussenpolitischen: 1
# aussenpolitischer: 1
# entscheide: 1
# stel-lungnahmen: 1
# geeigneter: 1
# verhandlungen: 1
# 56: 1
# zuständigkeitsbereichen: 1
# informieren: 1
# untergeordneten: 1
# direkt: 1
# verkehren;: 1
# landesverteidigung: 1
# 57: 1
# 58: 1
# milizprinzip: 1
# organisiert: 1
# kriegsverhinderung: 1
# friedens;: 1
# verteidigt: 1
# schwerwiegender: 1
# ausserordentlicher: 1
# lagen: 1
# 59: 1
# 60: 1
# militärgesetzgebung: 1
# militärische: 1
# 61: 1
# bewaffneter: 1
# konflikte: 1
# zivilschutzes: 1
# katastrophen: 1
# männer: 1
# frauen: 1
# 61a: 1
# bildungsraum: 1
# hohe: 1
# durchlässigkeit: 1
# bildungsraumes: 1
# vorkehren: 1
# bildende: 1
# berufsbezogene: 1
# bildungswege: 1
# schulwesen*: 1
# leitung: 1
# vollendeten: 1
# schulwesens: 1
# schuleintrittsalters: 1
# schulpflicht: 1
# bildungsstufen: 1
# übergängen: 1
# zustande: 1
# beginn: 1
# schuljahres: 1
# 63: 1
# breites: 1
# durchlässiges: 1
# 63a: 1
# wei-tere: 1
# anerkannte: 1
# entrichten: 1
# hochschulwesen: 1
# gleichbehandlung: 1
# studienstufen: 1
# übergänge: 1
# einheitliche: 1
# finanzierungsgrundsätze: 1
# binden: 1
# kostenintensiven: 1
# 64: 1
# innovation: 1
# forschungsstätten: 1
# 64a: 1
# bereiche: 1
# statistik: 1
# statistischen: 1
# register: 1
# gering: 1
# 66: 1
# studierende: 1
# bildungswesens: 1
# ausbildungsbeiträgen: 1
# schulhoheit: 1
# 67: 1
# förderungs-: 1
# schutzbedürfnissen: 1
# ausserschulische: 1
# 67a: 1
# hochwertigen: 1
# musikunterricht: 1
# musikunterrichts: 1
# jugend: 1
# musizieren: 1
# musikalisch: 1
# begabter: 1
# 68: 1
# sportschule: 1
# jugendsport: 1
# sportunterricht: 1
# 69: 1
# gesamtschweizerischem: 1
# musik: 1
# 70: 1
# sprachen: 1
# rätoromanischer: 1
# rätoromanische: 1
# amtssprache: 1
# einvernehmen: 1
# herkömmliche: 1
# gebiete: 1
# angestammten: 1
# sprachlichen: 1
# minderheiten: 1
# verständigung: 1
# austausch: 1
# mehrsprachigen: 1
# rätoromanischen: 1
# italienischen: 1
# 71: 1
# film: 1
# filmproduktion: 1
# filmkultur: 1
# filmangebots: 1
# 72: 1
# verhältnisses: 1
# friedens: 1
# verschiedenen: 1
# religionsgemeinschaften: 1
# minaretten: 1
# 73: 1
# nachhaltigkeit: 1
# ausgewogenes: 1
# erneuerungsfähigkeit: 1
# einerseits: 1
# beanspruchung: 1
# anderseits: 1
# 74: 1
# umweltschutz: 1
# natür-lichen: 1
# lästigen: 1
# vermieden: 1
# vermeidung: 1
# verursacher: 1
# 75: 1
# obliegt: 1
# zweckmässigen: 1
# haushälterischen: 1
# bodens: 1
# geordneten: 1
# erfordernisse: 1
# 75a: 1
# landesvermessung: 1
# amtliche: 1
# boden: 1
# zweitwohnungen*: 1
# gesamtbestand: 1
# wohneinheiten: 1
# wohnzwecke: 1
# genutzten: 1
# bruttogeschossfläche: 1
# erstwohnungsanteilplan: 1
# detaillierten: 1
# stand: 1
# seines: 1
# vollzugs: 1
# alljährlich: 1
# veröffentlichen: 1
# 76: 1
# haushälterische: 1
# schädigender: 1
# wassers: 1
# wasser-vorkommen: 1
# energieerzeugung: 1
# kühl-zwecke: 1
# wasserkreislauf: 1
# gewässerschutz: 1
# restwassermengen: 1
# wasserbau: 1
# stauanlagen: 1
# beeinflussung: 1
# niederschläge: 1
# wassernutzung: 1
# schranken: 1
# verkehrsbetriebe: 1
# nutzen;: 1
# entrichtet: 1
# damit: 1
# verbundene: 1
# beizug: 1
# einigen: 1
# stammt: 1
# 77: 1
# nutz-: 1
# wohlfahrtsfunktionen: 1
# 78: 1
# schont: 1
# landschaften: 1
# ortsbilder: 1
# geschichtliche: 1
# stätten: 1
# kulturdenkmäler;: 1
# erhält: 1
# ungeschmälert: 1
# gebietet: 1
# objekte: 1
# vertraglich: 1
# erwerben: 1
# sichern: 1
# pflanzenwelt: 1
# ausrottung: 1
# schönheit: 1
# gesamtschweizeri-scher: 1
# darin: 1
# gebaut: 1
# bodenveränderungen: 1
# vorgenommen: 1
# 79: 1
# artenvielfalt: 1
# fische: 1
# wild: 1
# säugetiere: 1
# vögel: 1
# tierschutz: 1
# tierhaltung: 1
# tierpflege;: 1
# tierversuche: 1
# tier;: 1
# tierischen: 1
# erzeugnissen;: 1
# tierhandel: 1
# tiertransporte;: 1
# töten: 1
# 81: 1
# grossen: 1
# teils: 1
# 81a: 1
# ausreichendes: 1
# öffentlichem: 1
# strasse: 1
# belange: 1
# schienengüterverkehrs: 1
# nutzerinnen: 1
# nutzern: 1
# bezahlten: 1
# preise: 1
# 82: 1
# aus;: 1
# durchgangsstrassen: 1
# gebührenfrei: 1
# bewilligen: 1
# netzes: 1
# benutzbarkeit: 1
# baut: 1
# unterhält: 1
# gemischten: 1
# alpenquerender: 1
# transitverkehr*: 1
# negativen: 1
# transitverkehrs: 1
# mass: 1
# schädlich: 1
# alpenquerende: 1
# gütertransitverkehr: 1
# unumgänglich: 1
# transitstrassen-kapazität: 1
# beschränkung: 1
# umfahrungsstrassen: 1
# ortschaften: 1
# durchgangsverkehr: 1
# entlasten: 1
# schwerverkehrsabgabe*: 1
# leistungs-: 1
# verbrauchsabhängige: 1
# verursacht: 1
# deckung: 1
# landverkehr: 1
# anteile: 1
# berg-: 1
# randgebieten: 1
# 85a: 1
# motorfahrzeuge: 1
# strassenverkehr*: 1
# verkehrsinfrastruktur: 1
# städten: 1
# nationalstrassenabgabe: 1
# 85a;: 1
# d;: 1
# zuschlags: 1
# a;: 1
# b;: 1
# 310: 1
# jahr;: 1
# betrags;: 1
# regel: 1
# kompensation: 1
# mehraufwendungen: 1
# ins: 1
# aufgenommene: 1
# strecken: 1
# zugewiesene: 1
# geführt: 1
# kombinierten: 1
# transports: 1
# begleiteter: 1
# motorfahrzeuge;: 1
# hauptstrassen;: 1
# schutzbauten: 1
# naturgewalten: 1
# landschaftsschutzes: 1
# motorfahrzeugverkehr: 1
# geöffnet: 1
# nationalstrassen;: 1
# verwaltung;: 1
# abzüglich: 1
# rückstellung: 1
# gebildet: 1
# zuzuweisen: 1
# gutzuschreiben: 1
# eisenbahnen: 1
# verkehrsträger*: 1
# eisenbahnverkehr: 1
# schifffahrt: 1
# luft-: 1
# raumfahrt: 1
# eisenbahninfrastruktur*: 1
# hauptlast: 1
# 85;: 1
# mehrwertsteuererhöhung: 1
# 3bis;: 1
# 2300: 1
# bundeshaushalt;: 1
# betrags: 1
# ergänzende: 1
# dritte: 1
# umweltschutzmassnahmen: 1
# sicherheitsmassnahmen: 1
# widerrechtlicher: 1
# handlungen: 1
# terroranschlägen: 1
# entführungen: 1
# obliegen;: 1
# sicherheitsniveaus: 1
# 88: 1
# velowege: 1
# velowegnetze: 1
# anlage: 1
# solcher: 1
# information: 1
# ersetzt: 1
# wege: 1
# aufheben: 1
# kommunikation: 1
# 89: 1
# breit: 1
# gefächerte: 1
# sichere: 1
# umweltverträgliche: 1
# energieversorgung: 1
# einheimischer: 1
# erneuerbarer: 1
# geräten: 1
# energietechniken: 1
# energiesparens: 1
# erneuerbaren: 1
# verbrauch: 1
# gebäuden: 1
# rechnung;: 1
# verhältnisse: 1
# tragbarkeit: 1
# kernenergie*: 1
# 91: 1
# lieferung: 1
# elektrischer: 1
# rohrleitungsanlagen: 1
# beförderung: 1
# flüssiger: 1
# gas-förmiger: 1
# brenn-: 1
# 92: 1
# preiswerte: 1
# fernmeldediensten: 1
# 93: 1
# entfaltung: 1
# meinungsbildung: 1
# unterhaltung: 1
# ereignisse: 1
# sachgerecht: 1
# dar: 1
# ansichten: 1
# ausdruck: 1
# pro-grammgestaltung: 1
# medien: 1
# programmbeschwerden: 1
# beschwerdeinstanz: 1
# 94: 1
# wirtschaftsordnung: 1
# gesamtwirtschaft: 1
# günstige: 1
# rahmenbedingungen: 1
# abweichungen: 1
# regalrechte: 1
# begründet: 1
# privatwirtschaftliche: 1
# erwerbstätigkeit*: 1
# wirtschaftsraum: 1
# anerkannten: 1
# ausbildungsabschluss: 1
# beruf: 1
# volkswirtschaft: 1
# privateigentums: 1
# unternehmensführung: 1
# kotierten: 1
# aktiengesellschaften: 1
# generalversammlung: 1
# gesamtsumme: 1
# vergütungen: 1
# (geld: 1
# wert: 1
# sachleistungen): 1
# geschäftsleitung: 1
# beirates: 1
# verwaltungsratspräsidentin: 1
# verwaltungsratspräsidenten: 1
# einzeln: 1
# vergütungsausschusses: 1
# stimmrechtsvertreterin: 1
# stimmrechtsvertreter: 1
# pensionskassen: 1
# gestimmt: 1
# elektronisch: 1
# fernabstimmen;: 1
# organ-: 1
# depotstimmrechtsvertretung: 1
# abgangs-: 1
# vergütung: 1
# prämie: 1
# firmenkäufe: 1
# -verkäufe: 1
# zusätzlichen: 1
# berater-: 1
# arbeitsvertrag: 1
# gruppe: 1
# juristische: 1
# delegiert: 1
# statuten: 1
# kredite: 1
# darlehen: 1
# erfolgs-: 1
# beteiligungspläne: 1
# anzahl: 1
# mandate: 1
# konzerns: 1
# arbeitsverträge: 1
# geschäftsleitungsmitglieder: 1
# widerhandlung: 1
# a–c: 1
# freiheitsstrafe: 1
# geldstrafe: 1
# jahresvergütungen: 1
# bestraft: 1
# 96: 1
# wettbewerbspolitik: 1
# volkswirtschaftlich: 1
# schädliche: 1
# kartellen: 1
# wettbewerbsbeschränkungen: 1
# verhinderung: 1
# preisbildung: 1
# marktmächtige: 1
# rechts;: 1
# 97: 1
# rechtsmittel: 1
# konsumentenorganisationen: 1
# berufs-: 1
# wirtschaftsverbänden: 1
# sehen: 1
# streitwert: 1
# schlichtungsverfahren: 1
# einfaches: 1
# rasches: 1
# gerichtsverfahren: 1
# 98: 1
# banken: 1
# versicherungen: 1
# banken-: 1
# börsenwesen;: 1
# kantonalbanken: 1
# finanzdienstleistungen: 1
# privatversicherungswesen: 1
# 99: 1
# währungswesen: 1
# ausgabe: 1
# münzen: 1
# banknoten: 1
# zentralbank: 1
# gesamtinteresse: 1
# dient;: 1
# erträgen: 1
# wäh-rungsreserven;: 1
# gold: 1
# reingewinn: 1
# dritteln: 1
# konjunkturpolitik: 1
# ausgeglichene: 1
# konjunkturelle: 1
# kreditwesen: 1
# aussenwirtschaft: 1
# einnahmen-: 1
# aus-gabenpolitik: 1
# konjunkturlage: 1
# stabilisierung: 1
# konjunktur: 1
# zuschläge: 1
# rabatte: 1
# abgeschöpften: 1
# stillzulegen;: 1
# individuell: 1
# zurückerstattet: 1
# indirekte: 1
# rabatten: 1
# arbeitsbeschaffung: 1
# arbeitsbeschaffungsreserven: 1
# verpflichten;: 1
# verwendungszwecke: 1
# aussenwirtschaftspolitik: 1
# inländischen: 1
# landesversorgung*: 1
# lebenswichtigen: 1
# machtpolitischer: 1
# kriegerischer: 1
# mangellagen: 1
# vermag: 1
# vorsorgliche: 1
# strukturpolitik*: 1
# wirtschaftszweige: 1
# zumutbare: 1
# selbsthilfemassnahmen: 1
# ausreichen: 1
# 104: 1
# beitrag: 1
# leistet: 1
# sicheren: 1
# bevölkerung;: 1
# kulturlandschaft;: 1
# dezentralen: 1
# ergänzend: 1
# zumutbaren: 1
# selbsthilfe: 1
# abweichend: 1
# bodenbewirtschaftenden: 1
# betriebe: 1
# multifunktionalen: 1
# ergänzt: 1
# bäuerliche: 1
# direktzahlungen: 1
# erzielung: 1
# entgelts: 1
# erbrachten: 1
# voraussetzung: 1
# ökologischen: 1
# leistungsnachweises: 1
# lohnenden: 1
# anreizen: 1
# produktionsformen: 1
# naturnah: 1
# tierfreundlich: 1
# deklaration: 1
# produk-tionsmethode: 1
# verarbeitungsverfahren: 1
# lebensmittel: 1
# beeinträchtigungen: 1
# überhöhten: 1
# düngstoffen: 1
# hilfsstoffen: 1
# för-dern: 1
# investitionshilfen: 1
# festigung: 1
# grundbesitzes: 1
# zweckgebundene: 1
# bundesmittel: 1
# 104a: 1
# ernährungssicherheit: 1
# sicherstellung: 1
# kulturlandes;: 1
# standortangepasste: 1
# ressourceneffiziente: 1
# lebensmittelproduktion;: 1
# ernährungswirtschaft;: 1
# grenzüberschreitende: 1
# handelsbeziehungen: 1
# entwick-lung: 1
# ernährungswirtschaft: 1
# beitragen;: 1
# ressourcenschonenden: 1
# 105: 1
# alkohol: 1
# reinigung: 1
# gebrannter: 1
# wir-kungen: 1
# alkoholkonsums: 1
# 106: 1
# geldspiele;: 1
# konzession: 1
# konzessionserteilung: 1
# gegebenheiten: 1
# ertragsabhängige: 1
# spielbankenabgabe;: 1
# bruttospielerträge: 1
# bewilligung: 1
# beaufsichtigung: 1
# unbegrenzten: 1
# offenstehen: 1
# mehreren: 1
# derselben: 1
# zufallsziehung: 1
# ähnlichen: 1
# prozedur: 1
# unterliegen;: 1
# jackpotsysteme: 1
# spielbanken;: 1
# sportwetten;: 1
# geschicklichkeitsspiele: 1
# telekommunikationsgestützt: 1
# durchgeführten: 1
# gefahren: 1
# aufsichtsmassnahmen: 1
# merkmale: 1
# spiele: 1
# spielangebots: 1
# reinerträge: 1
# spielen: 1
# gemeinnützige: 1
# zwecke: 1
# soziales: 1
# gemeinsames: 1
# organ: 1
# hälftig: 1
# vollzugsorgane: 1
# zusammengesetzt: 1
# 107: 1
# waffenzubehör: 1
# munition: 1
# vertrieb: 1
# durchfuhr: 1
# soziale: 1
# 108: 1
# wohnbau-: 1
# wohneigentumsförderung: 1
# wohnungs-: 1
# haus-eigentum: 1
# eigenbedarf: 1
# trägern: 1
# gemeinnützigen: 1
# rationalisierung: 1
# wohnkosten: 1
# baurationalisierung: 1
# bedürftigen: 1
# 109: 1
# missbräuche: 1
# missbräuchliche: 1
# mietzinse: 1
# anfechtbarkeit: 1
# missbräuchlicher: 1
# kündigungen: 1
# befristete: 1
# erstreckung: 1
# mietverhältnissen: 1
# rahmenmietverträgen: 1
# arbeit*: 1
# arbeitnehmer;: 1
# arbeitgeber-: 1
# arbeitnehmerseite: 1
# betrieblicher: 1
# beruflicher: 1
# angelegenheiten;: 1
# arbeitsvermittlung;: 1
# gesamtarbeitsverträgen: 1
# gesamtarbeitsverträge: 1
# august: 1
# arbeitsrechtlich: 1
# sonntagen: 1
# gleich-gestellt: 1
# bezahlt: 1
# 111: 1
# beruht: 1
# säulen: 1
# nämlich: 1
# dauernd: 1
# arbeitgebern: 1
# anwartschaftlichen: 1
# ansprüchen: 1
# steuer-: 1
# eigentumspolitik: 1
# 112: 1
# hinterlassenen: 1
# decken: 1
# höchstrente: 1
# maximal: 1
# doppelte: 1
# mindestrente: 1
# preisentwicklung: 1
# arbeit-geber: 1
# bezahlen;: 1
# linie: 1
# tabaksteuer: 1
# wassern: 1
# 112a: 1
# invalider*: 1
# betagten-: 1
# behindertenhilfe*: 1
# betagter: 1
# behinderter: 1
# vorsorge*: 1
# fortsetzung: 1
# gewohnten: 1
# lebenshaltung: 1
# vorsorgeeinrichtung;: 1
# vorsorgeeinrichtung: 1
# vorsorgeeinrich-tung: 1
# gruppen: 1
# selbstständigerwerbenden: 1
# vorsorgeeinrichtungen: 1
# mindestanforderungen: 1
# genügen;: 1
# lösung: 1
# 114: 1
# erwerbsersatz: 1
# erbringen: 1
# verhältnissen: 1
# arbeitslosenfürsorge: 1
# bedürftiger: 1
# bedürftige: 1
# wohnkanton: 1
# aus-nahmen: 1
# 116: 1
# genuss: 1
# gelangen: 1
# mutter-schaftsversicherung: 1
# 117: 1
# 117a: 1
# zugängliche: 1
# hoher: 1
# anerkennen: 1
# medizinischen: 1
# anforderungen: 1
# berufe;: 1
# abgeltung: 1
# 118: 1
# heilmitteln: 1
# betäubungsmitteln: 1
# übertragbarer: 1
# stark: 1
# verbreiteter: 1
# bösartiger: 1
# krankheiten: 1
# ionisierenden: 1
# strahlen: 1
# 118a: 1
# 118b: 1
# forschungsfreiheit: 1
# biologie: 1
# medizin: 1
# berechtigten: 1
# hinreichender: 1
# aufklärung: 1
# einwilligung: 1
# missverhältnis: 1
# durch-geführt: 1
# urteilsfähigen: 1
# gewonnen: 1
# lässt: 1
# erwarten: 1
# minimal: 1
# 119: 1
# humanbereich: 1
# klonens: 1
# keim-zellen: 1
# nichtmenschliches: 1
# menschliches: 1
# eingebracht: 1
# verschmolzen: 1
# unterstützten: 1
# angewendet: 1
# unfruchtbarkeit: 1
# übertragung: 1
# behoben: 1
# kind: 1
# eigenschaften: 1
# herbeizuführen: 1
# betreiben;: 1
# befruchtung: 1
# festgelegten: 1
# erlaubt;: 1
# viele: 1
# menschliche: 1
# entwickelt: 1
# unterstützte: 1
# embryonenspende: 1
# leihmutterschaft: 1
# getrieben: 1
# untersucht: 1
# registriert: 1
# offenbart: 1
# zustimmt: 1
# vorschreibt: 1
# 119a: 1
# transplantationsmedizin: 1
# transplantation: 1
# or-ganen: 1
# zuteilung: 1
# spende: 1
# ausserhumanbereich*: 1
# kreatur: 1
# tier: 1
# genetische: 1
# pflanzenarten: 1
# ausländer-: 1
# asylbereich*: 1
# ein-: 1
# ausreise: 1
# asyl: 1
# ausländerrechtlichen: 1
# status: 1
# vorsätzlichen: 1
# tötungsdelikts: 1
# vergewaltigung: 1
# sexualdelikts: 1
# gewaltdelikts: 1
# raub: 1
# menschenhandels: 1
# drogenhandels: 1
# einbruchsdelikts: 1
# rechtskräftig: 1
# missbräuchlich: 1
# sozialhilfe: 1
# bezogen: 1
# umschreibt: 1
# absätzen: 1
# zuständigen: 1
# auszuweisen: 1
# 5–15: 1
# belegen: 1
# wiederholungsfall: 1
# anzusetzen: 1
# missachtet: 1
# sonstwie: 1
# illegal: 1
# einreist: 1
# macht: 1
# strafbar: 1
# steuerung: 1
# zuwanderung*: 1
# steuert: 1
# zuwanderung: 1
# eigenständig: 1
# sämtliche: 1
# ausländerrechts: 1
# einbezug: 1
# asylwesens: 1
# dauerhaften: 1
# familiennachzug: 1
# sozialleistungen: 1
# jährlichen: 1
# erwerbstätige: 1
# gesamtwirtschaftlichen: 1
# vorranges: 1
# auszurichten;: 1
# grenzgängerinnen: 1
# grenzgänger: 1
# einzubeziehen: 1
# massgebende: 1
# erteilung: 1
# aufenthaltsbewilligungen: 1
# arbeitgebers: 1
# integrationsfähigkeit: 1
# eigenständige: 1
# existenzgrundlage: 1
# verstossen: 1
# 122: 1
# zivilrechts: 1
# zivilprozessrechts: 1
# zivilsachen: 1
# 123: 1
# strafrechts: 1
# strafprozessrechts: 1
# strafsachen: 1
# anstalten;: 1
# verbesserungen: 1
# erzieherische: 1
# jungen: 1
# vollziehen: 1
# 123a: 1
# gerichtsurteil: 1
# extrem: 1
# gefährlich: 1
# erachtet: 1
# therapierbar: 1
# eingestuft: 1
# rückfallrisikos: 1
# lebensende: 1
# verwahren: 1
# frühzeitige: 1
# entlassung: 1
# hafturlaub: 1
# erwiesen: 1
# täter: 1
# geheilt: 1
# somit: 1
# darstellt: 1
# sollte: 1
# neuen: 1
# haftung: 1
# rückfall: 1
# täters: 1
# übernommen: 1
# voneinander: 1
# erfahrenen: 1
# fachleuten: 1
# 123b: 1
# unverjährbarkeit: 1
# strafverfolgung: 1
# pornografischen: 1
# verfolgung: 1
# sexueller: 1
# pornografischer: 1
# taten: 1
# unverjährbar: 1
# 123c: 1
# massnahme: 1
# sexualdelikten: 1
# widerstand: 1
# unfähigen: 1
# weil: 1
# sexuelle: 1
# kindes: 1
# endgültig: 1
# ehrenamtliche: 1
# minderjährigen: 1
# auszuüben: 1
# 124: 1
# opferhilfe: 1
# schwierigkeiten: 1
# geraten: 1
# 125: 1
# finanzordnung: 1
# hält: 1
# gleichgewicht: 1
# bewilligenden: 1
# wirtschaftslage: 1
# geschätzten: 1
# überschreiten: 1
# ausgewiesenen: 1
# mehrausgaben: 1
# folgejahren: 1
# kompensieren: 1
# 127: 1
# ausgestaltung: 1
# steuerpflichtigen: 1
# grundzügen: 1
# zulässt: 1
# gleichmässigkeit: 1
# doppelbesteuerung: 1
# steuern*: 1
# juristischen: 1
# festsetzung: 1
# kalten: 1
# progression: 1
# periodisch: 1
# ausgeglichen: 1
# rohertrag: 1
# gesenkt: 1
# 129: 1
# steuerharmonisierung: 1
# gemeinden;: 1
# harmonisierungsbestrebungen: 1
# erstreckt: 1
# zeitliche: 1
# verfahrensrecht: 1
# steuerstrafrecht: 1
# steuertarife: 1
# steuerfreibeträge: 1
# ungerechtfertigte: 1
# vergünstigungen: 1
# mehrwertsteuer*: 1
# lieferungen: 1
# einschliesslich: 1
# eigenverbrauch: 1
# einfuhren: 1
# beherbergungsleistungen: 1
# altersaufbaus: 1
# reduzierte: 1
# 03: 1
# 3bis: 1
# sätze: 1
# zweckgebundenen: 1
# prämienverbilligung: 1
# krankenversicherung: 1
# entlastung: 1
# verbrauchssteuern*: 1
# tabak: 1
# tabakwaren;: 1
# wassern;: 1
# bier;: 1
# automobilen: 1
# bestandteilen;: 1
# erdöl: 1
# mineralölen: 1
# erdgas: 1
# verarbeitung: 1
# gewonnenen: 1
# produkten: 1
# flugtreibstoffen;: 1
# motorfahrzeug: 1
# antriebsmittel: 1
# reichen: 1
# ursachen: 1
# wirkungen: 1
# suchtproblemen: 1
# 132: 1
# wertpapieren: 1
# quittungen: 1
# versicherungsprämien: 1
# handelsverkehrs: 1
# erheben;: 1
# grundstück-: 1
# grundpfandverkehrs: 1
# beweglichem: 1
# kapitalvermögen: 1
# lotteriegewinnen: 1
# steuerertrag: 1
# 133: 1
# grenzüberschreitenden: 1
# warenverkehr: 1
# 134: 1
# ausschluss: 1
# kommunaler: 1
# was: 1
# steuerfrei: 1
# gleichartigen: 1
# belasten: 1
# 135: 1
# unterschiede: 1
# verringern;: 1
# minimale: 1
# gewährleisten;: 1
# übermässige: 1
# lasten: 1
# geografisch-topografischen: 1
# soziodemografischen: 1
# ausgleichen;: 1
# fördern;: 1
# wettbewerbsfähigkeit: 1
# nationalen: 1
# ausgleich: 1
# verfügung: 1
# 136: 1
# bundessachen: 1
# schweizern: 1
# zurückgelegt: 1
# geisteskrankheit: 1
# geistesschwäche: 1
# entmündigt: 1
# nationalratswahlen: 1
# abstimmungen: 1
# teilnehmen: 1
# referenden: 1
# bundesangelegenheiten: 1
# unterzeichnen: 1
# 137: 1
# 138: 1
# vorschlagen: 1
# begehren: 1
# 139: 1
# veröf-fentlichung: 1
# zwin-gende: 1
# ungültig: 1
# einverstanden: 1
# sinn: 1
# lehnt: 1
# abstimmung;: 1
# folge: 1
# empfiehlt: 1
# gegenüberstellen: 1
# 139a: 1
# 139b: 1
# gegen-entwurf: 1
# zustimmen: 1
# angeben: 1
# volksstimmen: 1
# grössere: 1
# summe: 1
# 140: 1
# obligatorisches: 1
# kollektive: 1
# supranationalen: 1
# gemeinschaften;: 1
# abgelehnt: 1
# durchzuführen: 1
# 141: 1
# fakultatives: 1
# acht: 1
# tagen: 1
# erlasses: 1
# bundesgesetze;: 1
# erklärte: 1
# vorsehen;: 1
# unbefristet: 1
# unkündbar: 1
# wichtige: 1
# enthalten: 1
# bundesgesetzen: 1
# 141a: 1
# obligatorischen: 1
# fakultativen: 1
# gesetzesänderungen: 1
# 142: 1
# erforderliche: 1
# mehrheiten: 1
# ausspricht: 1
# aussprechen: 1
# halbe: 1
# 143: 1
# wählbarkeit: 1
# stimm-berechtigten: 1
# 144: 1
# angehören: 1
# vollamtlichen: 1
# amt: 1
# bekleiden: 1
# 145: 1
# 146: 1
# staatshaftung: 1
# haftet: 1
# schäden: 1
# widerrechtlich: 1
# verursachen: 1
# 147: 1
# vernehmlassungsverfahren: 1
# interessierten: 1
# kreise: 1
# wichtiger: 1
# vorhaben: 1
# grosser: 1
# tragweite: 1
# stellungnahme: 1
# eingeladen: 1
# 148: 1
# vorbehalt: 1
# gewalt: 1
# ständerat;: 1
# gleichgestellt: 1
# 149: 1
# 200: 1
# direkter: 1
# proporzes: 1
# findet: 1
# wahlkreis: 1
# sitze: 1
# bevölkerungszahl: 1
# sitz: 1
# 150: 1
# abgeordneten;: 1
# 151: 1
# versammeln: 1
# viertel: 1
# session: 1
# 152: 1
# präsidentin: 1
# präsidenten: 1
# erste: 1
# ersten: 1
# zweite: 1
# zweiten: 1
# 153: 1
# parlamentarische: 1
# auskunftsrechte: 1
# ein-sichtsrechte: 1
# untersuchungsbefugnisse: 1
# 154: 1
# 155: 1
# dienststellen: 1
# beiziehen: 1
# 156: 1
# getrennte: 1
# übereinstimmung: 1
# beider: 1
# sicherzustellen: 1
# teilungültigkeit: 1
# volksinitiative;: 1
# anregung;: 1
# gutgeheissenen: 1
# einleitung: 1
# nachtrag: 1
# 157: 1
# nationalratspräsidentin: 1
# nationalratspräsidenten: 1
# vorzunehmen;: 1
# ent-scheiden;: 1
# auszusprechen: 1
# versammelt: 1
# anlässen: 1
# entgegennahme: 1
# erklärungen: 1
# 158: 1
# verhandlungsfähigkeit: 1
# erforderliches: 1
# gültig: 1
# anwesend: 1
# vereinigten: 1
# dringlicherklärung: 1
# bundesgesetzen;: 1
# subventionsbestimmungen: 1
# verpflichtungskredite: 1
# zahlungsrahmen: 1
# einmalige: 1
# wiederkehrende: 1
# ziehen;: 1
# beträge: 1
# 160: 1
# antragsrecht: 1
# ratsmitglied: 1
# fraktion: 1
# parlamentarischen: 1
# kommission: 1
# initiativen: 1
# ratsmitglieder: 1
# stehenden: 1
# geschäft: 1
# anträge: 1
# 161: 1
# instruktionsverbot: 1
# weisungen: 1
# interessenbindungen: 1
# 162: 1
# bundes-kanzlerin: 1
# äusserungen: 1
# rechtlich: 1
# gezogen: 1
# 163: 1
# ergehen: 1
# bundesbeschlusses;: 1
# bundes-beschluss: 1
# einfacher: 1
# 164: 1
# rechtsetzenden: 1
# grundlegenden: 1
# verfassungsmässiger: 1
# abgabepflichtigen: 1
# abgaben;: 1
# bundesrechts;: 1
# rechtsetzungsbefugnisse: 1
# 165: 1
# dringlichkeit: 1
# aufschub: 1
# duldet: 1
# sofort: 1
# gesetzt: 1
# erneuert: 1
# 166: 1
# gestaltung: 1
# aussenpolitik: 1
# verträge;: 1
# völkerrechtlichem: 1
# 167: 1
# voran-schlag: 1
# 168: 1
# general: 1
# vorzu-nehmen: 1
# bestätigen: 1
# 169: 1
# delegationen: 1
# aufsichtskommis-sionen: 1
# geheimhaltungspflichten: 1
# entgegengehalten: 1
# 170: 1
# überprüft: 1
# 171: 1
# erteilen: 1
# instrumente: 1
# welchen: 1
# einwirken: 1
# 172: 1
# 173: 1
# ausserordentliche: 1
# umstände: 1
# einfache: 1
# ordnet: 1
# durchsetzung: 1
# befindet: 1
# gekommener: 1
# wirkt: 1
# planungen: 1
# staatstätigkeit: 1
# einzelakte: 1
# ausdrücklich: 1
# bundes-behörden: 1
# k: 1
# spricht: 1
# amnestie: 1
# keiner: 1
# 174: 1
# leitende: 1
# vollziehende: 1
# 175: 1
# sieben: 1
# schweizerbürgerinnen: 1
# schweizerbürgern: 1
# sprach-regionen: 1
# vertreten: 1
# 176: 1
# vizepräsident: 1
# 177: 1
# kollegial-: 1
# departementalprinzip: 1
# kollegium: 1
# unterstellten: 1
# verwaltungseinheiten: 1
# erledigung: 1
# übertragen;: 1
# rechtsschutz: 1
# 178: 1
# leitet: 1
# zweckmässige: 1
# zielgerichtete: 1
# departemente: 1
# gegliedert;: 1
# departement: 1
# mitglied: 1
# verwaltungsaufgaben: 1
# 179: 1
# stabsstelle: 1
# geleitet: 1
# 180: 1
# plant: 1
# überwiegende: 1
# 181: 1
# entwürfe: 1
# 182: 1
# urteile: 1
# richterlicher: 1
# 183: 1
# erarbeitet: 1
# finanzplan: 1
# entwirft: 1
# ordnungsgemässe: 1
# 184: 1
# besorgt: 1
# mitwirkungsrechte: 1
# bundesversammlung;: 1
# vertritt: 1
# aussen: 1
# unterzeichnet: 1
# ratifiziert: 1
# 185: 1
# äussere: 1
# innere: 1
# gestützt: 1
# eingetretenen: 1
# drohenden: 1
# störungen: 1
# dringlichen: 1
# truppen: 1
# aufbieten: 1
# angehörige: 1
# dauert: 1
# voraussichtlich: 1
# länger: 1
# wochen: 1
# einzuberufen: 1
# 186: 1
# pflegt: 1
# 187: 1
# auf-gaben: 1
# erstattet: 1
# bericht: 1
# geschäftsführung: 1
# zustehen: 1
# 188: 1
# rechtsprechende: 1
# 189: 1
# verletzung: 1
# bundesrecht;: 1
# völkerrecht;: 1
# interkantonalem: 1
# recht;: 1
# rechten;: 1
# garantien: 1
# körperschaften;: 1
# 1bis: 1
# akte: 1
# angefochten: 1
# 190: 1
# massgebendes: 1
# rechtsanwendenden: 1
# massgebend: 1
# 191: 1
# rechtsfrage: 1
# grundsätzlicher: 1
# sachgebiete: 1
# offensichtlich: 1
# unbegründete: 1
# vereinfachtes: 1
# 191a: 1
# strafgericht;: 1
# erstinstanzlich: 1
# straffälle: 1
# gerichtsbarkeit: 1
# bundesstrafgerichts: 1
# 191b: 1
# bestellen: 1
# zivilrecht-lichen: 1
# straffällen: 1
# einsetzen: 1
# 191c: 1
# richterlichen: 1
# rechtsprechenden: 1
# 192: 1
# beruhende: 1
# 193: 1
# vorgeschlagen: 1
# uneinig: 1
# ent-scheidet: 1
# 194: 1
# verletzen: 1
# 195: 1
# revidierte: 1
# 196: 1
# (alpenquerender: 1
# transitverkehr): 1
# verlagerung: 1
# gütertransitverkehrs: 1
# alpengebietes: 1
# (pauschale: 1
# schwerverkehrsabgabe): 1
# geöffneten: 1
# fr: 1
# lastwagen: 1
# sattelmotorfahrzeuge: 1
# 3000: 1
# 1500: 1
# gesellschaftswagen: 1
# abgabesätze: 1
# strassenverkehrskosten: 1
# rechtfertigen: 1
# tarifkategorie: 1
# allfällige: 1
# gewichtskategorien: 1
# strassenverkehrsgesetz: 1
# 1958: 1
# ganze: 1
# entsprechend: 1
# abgestufte: 1
# abgabesätze;: 1
# ansätze: 1
# ver-zichtet: 1
# schwerverkehrsabgabegesetzes: 1
# 1997: 1
# (verwendung: 1
# strassenverkehr): 1
# (eisenbahnen: 1
# verkehrsträger): 1
# (eisenbahninfrastruktur): 1
# eisenbahn-alpentransversale: 1
# (neat): 1
# bahn: 1
# anschluss: 1
# ost-: 1
# westschweiz: 1
# europäische: 1
# eisenbahn-hochleistungsnetz: 1
# lärmschutzes: 1
# entlang: 1
# eisenbahnstrecken: 1
# aktive: 1
# passive: 1
# anschliessend: 1
# berechnen: 1
# 2ter: 1
# prozentsatz: 1
# davor: 1
# bun-desgesetzen: 1
# grossprojekt: 1
# ganzes: 1
# ausführungsreife: 1
# nachzuweisen: 1
# neat-projekt: 1
# bauphasen: 1
# bewilligt: 1
# verpflichtungskrediten: 1
# bauetappen: 1
# zeitplan: 1
# bauarbeiten: 1
# (rückzahlung: 1
# bevorschussung): 1
# erwähnten: 1
# (kernenergie): 1
# september: 1
# inbetriebnahme-: 1
# betriebsbewilligungen: 1
# erzeugung: 1
# (privatwirtschaftliche: 1
# erwerbstätigkeit): 1
# gegenseitigen: 1
# ausbildungsabschlüssen: 1
# (landesversorgung): 1
# brotgetreide: 1
# backmehl: 1
# (strukturpolitik): 1
# bestehende: 1
# regelungen: 1
# beibehalten: 1
# bedeutender: 1
# zweigs: 1
# gastgewerbes: 1
# eröffnung: 1
# betrieben: 1
# bedürfnis: 1
# (bundesfeiertag): 1
# geänderten: 1
# feiertage: 1
# arbeitsgesetzes: 1
# 1964: 1
# angerechnet: 1
# (berufliche: 1
# vorsorge): 1
# versicherte: 1
# eintrittsgeneration: 1
# deswegen: 1
# volle: 1
# beitragszeit: 1
# sollen: 1
# einkommens: 1
# gesetzes: 1
# gesetzlich: 1
# vorgeschriebenen: 1
# mindestschutz: 1
# (dauer: 1
# steuererhebung): 1
# (mehrwertsteuer): 1
# mehrwertsteuersätze: 1
# 2011: 1
# 2017: 1
# folgt: 1
# ausgleichsfonds: 1
# mehrwertsteuergesetzes: 1
# 2009: 1
# verlängerung: 1
# 2030: 1
# 197: 1
# uno: 1
# generalsekretär: 1
# (uno): 1
# aufnahme: 1
# erklärung: 1
# un-charta: 1
# enthaltenen: 1
# (schulwesen): 1
# (einschliesslich: 1
# heilpädagogischen: 1
# früherziehung: 1
# bg: 1
# 1959: 1
# invalidenversicherung): 1
# sonderschulkonzepte: 1
# (nationalstrassen): 1
# 1960: 1
# aufgeführten: 1
# bb: 1
# okt: 1
# kantonen): 1
# fertig: 1
# kostenanteil: 1
# (förderung: 1
# invalider): 1
# anstalten: 1
# werkstätten: 1
# wohnheime: 1
# behindertenkonzepte: 1
# ausserkantonalen: 1
# platzierungen: 1
# (betagten-: 1
# behindertenhilfe): 1
# 101bis: 1
# 1946: 1
# hinterlassenenversicherung: 1
# betagte: 1
# behinderte: 1
# ausgerichtet: 1
# finanzierungsregelung: 1
# (gentechnologie: 1
# ausserhumanbereich): 1
# verfassungsbestimmung: 1
# gentechnikfrei: 1
# eingeführt: 1
# gebracht: 1
# vermehrungsfähige: 1
# pflanzenteile: 1
# saatgut: 1
# gartenbauliche: 1
# forstwirt-schaftliche: 1
# (aufenthalt: 1
# ausländern): 1
# 3–6: 1
# definieren: 1
# strafbestimmungen: 1
# bezüglich: 1
# illegaler: 1
# einreise: 1
# (zweitwohnungen): 1
# nötigen: 1
# erstellung: 1
# registrierung: 1
# grundbuch: 1
# baubewilligungen: 1
# nichtig: 1
# (steuerung: 1
# zuwanderung): 1
# anzupassen: 1
# getreten: 1
# zeitpunkt: 1
# hin: 1
# (verbot: 1
# gesichts): 1
# zweier: 1
# erarbeiten: 1
# datum: 1
# inkrafttretens: 1
# schlussbestimmungen: 1
# ii: 1
# gesetzesrecht: 1
# überführen: 1
# 32quater: 1
# hausieren: 1
# getränken: 1
# umherziehen: 1
# 36quinquies: 1
# zweiter–letzter: 1
# klasse: 1
# tonnen: 1
# überwachen: 1
# 121bis: 1
# stimmzettel: 1
# uneingeschränkt: 1
# treten: 1
# vorziehen: 1
# sollten: 1
# absolute: 1
# ermittelt: 1
# unbeantwortete: 1
# betracht: 1
# sowohl: 1
# iii: 1
# bundesver-sammlung: 1
# formal: 1
# iv: 1

# %% [markdown]
# ***

# %% [markdown]
# # Credits
#
# <div>Hantel Icon von <a href="https://www.freepik.com" title="Freepik">Freepik</a> bei <a href="https://www.flaticon.com/" title="Flaticon">www.flaticon.com</a></div>
